# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import json
import requests

# %% [markdown]
# ## Get Current Data from Lending Club

# %%
api_key =open('apikey.txt','r').read()

headers = {'Authorization':api_key}
url='https://api.lendingclub.com/api/investor/v1/loans/listing'

r=requests.get(url, headers=headers)

# %%
type(r.json())
# Out:
# dict

# %%
r.json()
# Out:
# {'asOfDate': '2018-11-19T13:16:47.871-08:00',
#  'loans': [{'id': 143409220,
#    'memberId': 167412076,
#    'loanAmount': 17000.0,
#    'fundedAmount': 2100.0,
#    'term': 36,
#    'intRate': 11.8,
#    'expDefaultRate': 4.53,
#    'serviceFeeRate': 0.99,
#    'installment': 563.03,
#    'grade': 'B',
#    'subGrade': 'B4',
#    'empLength': None,
#    'homeOwnership': 'RENT',
#    'annualInc': 65000.0,
#    'isIncV': 'NOT_VERIFIED',
#    'acceptD': '2018-11-10T09:18:17.000-08:00',
#    'expD': '2018-12-19T10:00:00.000-08:00',
#    'listD': '2018-11-19T10:00:00.000-08:00',
#    'creditPullD': '2018-11-10T09:12:43.000-08:00',
#    'reviewStatusD': '2018-11-19T06:17:31.000-08:00',
#    'reviewStatus': 'APPROVED',
#    'desc': None,
#    'purpose': 'credit_card',
#    'addrZip': '806xx',
#    'addrState': 'CO',
#    'investorCount': None,
#    'ilsExpD': '2018-11-19T10:00:00.000-08:00',
#    'initialListStatus': 'F',
#    'empTitle': None,
#    'accNowDelinq': 0,
#    'accOpenPast24Mths': 3,
#    'bcOpenToBuy': 1722,
#    'percentBcGt75': 50.0,
#    'bcUtil': 87.2,
#    'dti': 28.56,
#    'delinq2Yrs': 0,
#    'delinqAmnt': 0.0,
#    'earliestCrLine': '2013-12-09T16:00:00.000-08:00',
#    'ficoRangeLow': 665,
#    'ficoRangeHigh': 669,
#    'inqLast6Mths': 0,
#    'mthsSinceLastDelinq': None,
#    'mthsSinceLastRecord': None,
#    'mthsSinceRecentInq': 10,
#    'mthsSinceRecentRevolDelinq': None,
#    'mthsSinceRecentBc': 3,
#    'mortAcc': 0,
#    'openAcc': 6,
#    'pubRec': 0,
#    'totalBalExMort': 78766,
#    'revolBal': 17023.0,
#    'revolUtil': 64.2,
#    'totalBcLimit': 13500,
#    'totalAcc': 18,
#    'totalIlHighCreditLimit': 70266,
#    'numRevAccts': 5,
#    'mthsSinceRecentBcDlq': None,
#    'pubRecBankruptcies': 0,
#    'numAcctsEver120Ppd': 0,
#    'chargeoffWithin12Mths': 0,
#    'collections12MthsExMed': 0,
#    'taxLiens': 0,
#    'mthsSinceLastMajorDerog': None,
#    'numSats': 6,
#    'numTlOpPast12m': 2,
#    'moSinRcntTl': 3,
#    'totHiCredLim': 96766,
#    'totCurBal': 78766,
#    'avgCurBal': 13128,
#    'numBcTl': 2,
#    'numActvBcTl': 2,
#    'numBcSats': 2,
#    'pctTlNvrDlq': 100,
#    'numTl90gDpd24m': 0,
#    'numTl30dpd': 0,
#    'numTl120dpd2m': 0,
#    'numIlTl': 13,
#    'moSinOldIlAcct': 59,
#    'numActvRevTl': 3,
#    'moSinOldRevTlOp': 44,
#    'moSinRcntRevTlOp': 3,
#    'totalRevHiLim': 26500,
#    'numRevTlBalGt0': 3,
#    'numOpRevTl': 4,
#    'totCollAmt': 0,
#    'applicationType': 'INDIVIDUAL',
#    'annualIncJoint': None,
#    'dtiJoint': None,
#    'isIncVJoint': None,
#    'openAcc6m': 2,
#    'openIl12m': 1,
#    'openIl24m': 2,
#    'mthsSinceRcntIl': 6,
#    'totalBalIl': 61743.0,
#    'iLUtil': 91.9,
#    'openRv12m': 1,
#    'openRv24m': 1,
#    'maxBalBc': 10789.0,
#    'allUtil': 69.6,
#    'inqFi': 0,
#    'totalCuTl': 7,
#    'inqLast12m': 1,
#    'mtgPayment': 0.0,
#    'housingPayment': None,
#    'secAppFicoRangeLow': None,
#    'secAppFicoRangeHigh': None,
#    'secAppEarliestCrLine': None,
#    'secAppInqLast6Mths': None,
#    'secAppMortAcc': None,
#    'secAppOpenAcc': None,
#    'secAppRevolUtil': None,
#    'secAppNumRevAccts': None,
#    'secAppChargeoffWithin12Mths': None,
#    'secAppCollections12MthsExMed': None,
#    'secAppMthsSinceLastMajorDerog': None,
#    'revolBalJoint': None,
#    'disbursementMethod': 'DIRECT_PAY',
#    'openActIl': 2,
#    'secAppOpenActIl': None},
#   {'id': 143665138,
#    'memberId': 167862083,
#    'loanAmount': 13300.0,
#    'fundedAmount': 9900.0,
#    'term': 36,
#    'intRate': 23.4,
#    'expDefaultRate': 15.49,
#    'serviceFeeRate': 1.62,
#    'installment': 517.62,
#    'grade': 'E',
#    'subGrade': 'E1',
#    'empLength': 12,
#    'homeOwnership': 'RENT',
#    'annualInc': 40000.0,
#    'isIncV': 'NOT_VERIFIED',
#    'acceptD': '2018-11-15T12:00:59.000-08:00',
#    'expD': '2018-12-19T10:00:00.000-08:00',
#    'listD': '2018-11-19T10:00:00.000-08:00',
#    'creditPullD': '2018-11-15T11:58:41.000-08:00',
#    'reviewStatusD': '2018-11-19T06:43:37.000-08:00',
#    'reviewStatus': 'APPROVED',
#    'desc': None,
#    'purpose': 'debt_consolidation',
#    'addrZip': '370xx',
#    'addrState': 'TN',
#    'investorCount': None,
#    'ilsExpD': '2018-11-19T10:00:00.000-08:00',
#    'initialListStatus': 'F',
#    'empTitle': 'Solution Specialist ',
#    'accNowDelinq': 0,
#    'accOpenPast24Mths': 3,
#    'bcOpenToBuy': 6576,
#    'percentBcGt75': 66.7,
#    'bcUtil': 61.1,
#    'dti': 22.74,
#    'delinq2Yrs': 0,
#    'delinqAmnt': 0.0,
#    'earliestCrLine': '2011-02-14T16:00:00.000-08:00',
#    'ficoRangeLow': 700,
#    'ficoRangeHigh': 704,
#    'inqLast6Mths': 0,
#    'mthsSinceLastDelinq': None,
#    'mthsSinceLastRecord': None,
#    'mthsSinceRecentInq': None,
#    'mthsSinceRecentRevolDelinq': None,
#    'mthsSinceRecentBc': 22,
#    'mortAcc': 0,
#    'openAcc': 5,
#    'pubRec': 0,
#    'totalBalExMort': 24134,
#    'revolBal': 10324.0,
#    'revolUtil': 61.1,
#    'totalBcLimit': 16900,
#    'totalAcc': 5,
#    'totalIlHighCreditLimit': 19176,
#    'numRevAccts': 3,
#    'mthsSinceRecentBcDlq': None,
#    'pubRecBankruptcies': 0,
#    'numAcctsEver120Ppd': 0,
#    'chargeoffWithin12Mths': 0,
#    'collections12MthsExMed': 0,
#    'taxLiens': 0,
#    'mthsSinceLastMajorDerog': None,
#    'numSats': 5,
#    'numTlOpPast12m': 1,
#    'moSinRcntTl': 6,
#    'totHiCredLim': 36076,
#    'totCurBal': 24134,
#    'avgCurBal': 4827,
#    'numBcTl': 3,
#    'numActvBcTl': 3,
#    'numBcSats': 3,
#    'pctTlNvrDlq': 100,
#    'numTl90gDpd24m': 0,
#    'numTl30dpd': 0,
#    'numTl120dpd2m': 0,
#    'numIlTl': 2,
#    'moSinOldIlAcct': 21,
#    'numActvRevTl': 3,
#    'moSinOldRevTlOp': 93,
#    'moSinRcntRevTlOp': 22,
#    'totalRevHiLim': 16900,
#    'numRevTlBalGt0': 3,
#    'numOpRevTl': 3,
#    'totCollAmt': 0,
#    'applicationType': 'INDIVIDUAL',
#    'annualIncJoint': None,
#    'dtiJoint': None,
#    'isIncVJoint': None,
#    'openAcc6m': 1,
#    'openIl12m': 1,
#    'openIl24m': 2,
#    'mthsSinceRcntIl': 6,
#    'totalBalIl': 13810.0,
#    'iLUtil': 72.0,
#    'openRv12m': 0,
#    'openRv24m': 1,
#    'maxBalBc': 5194.0,
#    'allUtil': 66.9,
#    'inqFi': 0,
#    'totalCuTl': 0,
#    'inqLast12m': 0,
#    'mtgPayment': 0.0,
#    'housingPayment': None,
#    'secAppFicoRangeLow': None,
#    'secAppFicoRangeHigh': None,
#    'secAppEarliestCrLine': None,
#    'secAppInqLast6Mths': None,
#    'secAppMortAcc': None,
#    'secAppOpenAcc': None,
#    'secAppRevolUtil': None,
#    'secAppNumRevAccts': None,
#    'secAppChargeoffWithin12Mths': None,
#    'secAppCollections12MthsExMed': None,
#    'secAppMthsSinceLastMajorDerog': None,
#    'revolBalJoint': None,
#    'disbursementMethod': 'DIRECT_PAY',
#    'openActIl': 2,
#    'secAppOpenActIl': None},
#   {'id': 143608470,
#    'memberId': 167653182,
#    'loanAmount': 15000.0,
#    'fundedAmount': 9625.0,
#    'term': 36,
#    'intRate': 15.02,
#    'expDefaultRate': 7.25,
#    'serviceFeeRate': 1.16,
#    'installment': 520.13,
#    'grade': 'C',
#    'subGrade': 'C3',
#    'empLength': 84,
#    'homeOwnership': 'RENT',
#    'annualInc': 75000.0,
#    'isIncV': 'NOT_VERIFIED',
#    'acceptD': '2018-11-15T09:39:59.000-08:00',
#    'expD': '2018-12-19T10:00:00.000-08:00',
#    'listD': '2018-11-19T10:00:00.000-08:00',
#    'creditPullD': '2018-11-15T09:34:17.000-08:00',
#    'reviewStatusD': '2018-11-19T08:08:35.000-08:00',
#    'reviewStatus': 'APPROVED',
#    'desc': None,
#    'purpose': 'home_improvement',
#    'addrZip': '329xx',
#    'addrState': 'FL',
#    'investorCount': None,
#    'ilsExpD': '2018-11-19T10:00:00.000-08:00',
#    'initialListStatus': 'F',
#    'empTitle': 'owner',
#    'accNowDelinq': 0,
#    'accOpenPast24Mths': 2,
#    'bcOpenToBuy': 17945,
#    'percentBcGt75': 25.0,
#    'bcUtil': 54.5,
#    'dti': 16.51,
#    'delinq2Yrs': 0,
#    'delinqAmnt': 0.0,
#    'earliestCrLine': '2007-09-14T17:00:00.000-07:00',
#    'ficoRangeLow': 715,
#    'ficoRangeHigh': 719,
#    'inqLast6Mths': 0,
#    'mthsSinceLastDelinq': None,
#    'mthsSinceLastRecord': None,
#    'mthsSinceRecentInq': None,
#    'mthsSinceRecentRevolDelinq': None,
#    'mthsSinceRecentBc': 22,
#    'mortAcc': 0,
#    'openAcc': 16,
#    'pubRec': 0,
#    'totalBalExMort': 27855,
#    'revolBal': 24062.0,
#    'revolUtil': 45.4,
#    'totalBcLimit': 39400,
#    'totalAcc': 25,
#    'totalIlHighCreditLimit': 15172,
#    'numRevAccts': 21,
#    'mthsSinceRecentBcDlq': None,
#    'pubRecBankruptcies': 0,
#    'numAcctsEver120Ppd': 0,
#    'chargeoffWithin12Mths': 0,
#    'collections12MthsExMed': 0,
#    'taxLiens': 0,
#    'mthsSinceLastMajorDerog': None,
#    'numSats': 16,
#    'numTlOpPast12m': 0,
#    'moSinRcntTl': 19,
#    'totHiCredLim': 70697,
#    'totCurBal': 27855,
#    'avgCurBal': 1741,
#    'numBcTl': 13,
#    'numActvBcTl': 5,
#    'numBcSats': 8,
#    'pctTlNvrDlq': 100,
#    'numTl90gDpd24m': 0,
#    'numTl30dpd': 0,
#    'numTl120dpd2m': 0,
#    'numIlTl': 3,
#    'moSinOldIlAcct': 114,
#    'numActvRevTl': 8,
#    'moSinOldRevTlOp': 134,
#    'moSinRcntRevTlOp': 19,
#    'totalRevHiLim': 53000,
#    'numRevTlBalGt0': 8,
#    'numOpRevTl': 14,
#    'totCollAmt': 0,
#    'applicationType': 'INDIVIDUAL',
#    'annualIncJoint': None,
#    'dtiJoint': None,
#    'isIncVJoint': None,
#    'openAcc6m': 0,
#    'openIl12m': 0,
#    'openIl24m': 0,
#    'mthsSinceRcntIl': 27,
#    'totalBalIl': 3793.0,
#    'iLUtil': 25.0,
#    'openRv12m': 0,
#    'openRv24m': 2,
#    'maxBalBc': 6593.0,
#    'allUtil': 39.4,
#    'inqFi': 0,
#    'totalCuTl': 1,
#    'inqLast12m': 0,
#    'mtgPayment': 0.0,
#    'housingPayment': 1300.0,
#    'secAppFicoRangeLow': None,
#    'secAppFicoRangeHigh': None,
#    'secAppEarliestCrLine': None,
#    'secAppInqLast6Mths': None,
#    'secAppMortAcc': None,
#    'secAppOpenAcc': None,
#    'secAppRevolUtil': None,
#    'secAppNumRevAccts': None,
#    'secAppChargeoffWithin12Mths': None,
#    'secAppCollections12MthsExMed': None,
#    'secAppMthsSinceLastMajorDerog': None,
#    'revolBalJoint': None,
#    'disbursementMethod': 'CASH',
#    'openActIl': 1,
#    'secAppOpenActIl': None},
#   {'id': 143843142,
#    'memberId': 168328211,
#    'loanAmount': 10000.0,
#    'fundedAmount': 9900.0,
#    'term': 36,
#    'intRate': 23.4,
#    'expDefaultRate': 15.49,
#    'serviceFeeRate': 1.62,
#    'installment': 389.19,
#    'grade': 'E',
#    'subGrade': 'E1',
#    'empLength': 24,
#    'homeOwnership': 'MORTGAGE',
#    'annualInc': 50000.0,
#    'isIncV': 'SOURCE_VERIFIED',
#    'acceptD': '2018-11-18T18:00:49.000-08:00',
#    'expD': '2018-12-19T10:00:00.000-08:00',
#    'listD': '2018-11-19T10:00:00.000-08:00',
#    'creditPullD': '2018-11-18T17:51:00.000-08:00',
#    'reviewStatusD': '2018-11-19T06:39:50.000-08:00',
#    'reviewStatus': 'APPROVED',
#    'desc': None,
#    'purpose': 'debt_consolidation',
#    'addrZip': '272xx',
#    'addrState': 'NC',
#    'investorCount': None,
#    'ilsExpD': '2018-11-19T10:00:00.000-08:00',
#    'initialListStatus': 'F',
#    'empTitle': 'Information technology admin',
#    'accNowDelinq': 0,
#    'accOpenPast24Mths': 7,
#    'bcOpenToBuy': 509,
#    'percentBcGt75': 100.0,
#    'bcUtil': 94.5,
#    'dti': 14.67,
#    'delinq2Yrs': 0,
#    'delinqAmnt': 0.0,
#    'earliestCrLine': '2008-01-18T16:00:00.000-08:00',
#    'ficoRangeLow': 665,
#    'ficoRangeHigh': 669,
#    'inqLast6Mths': 0,
#    'mthsSinceLastDelinq': 27,
#    'mthsSinceLastRecord': None,
#    'mthsSinceRecentInq': 10,
#    'mthsSinceRecentRevolDelinq': 27,
#    'mthsSinceRecentBc': 9,
#    'mortAcc': 1,
#    'openAcc': 8,
#    'pubRec': 0,
#    'totalBalExMort': 11171,
#    'revolBal': 9509.0,
#    'revolUtil': 69.4,
#    'totalBcLimit': 9200,
#    'totalAcc': 15,
#    'totalIlHighCreditLimit': 13354,
#    'numRevAccts': 13,
#    'mthsSinceRecentBcDlq': None,
#    'pubRecBankruptcies': 0,
#    'numAcctsEver120Ppd': 0,
#    'chargeoffWithin12Mths': 0,
#    'collections12MthsExMed': 0,
#    'taxLiens': 0,
#    'mthsSinceLastMajorDerog': 27,
#    'numSats': 8,
#    'numTlOpPast12m': 4,
#    'moSinRcntTl': 3,
#    'totHiCredLim': 85560,
#    'totCurBal': 68980,
#    'avgCurBal': 8623,
#    'numBcTl': 7,
#    'numActvBcTl': 3,
#    'numBcSats': 3,
#    'pctTlNvrDlq': 93,
#    'numTl90gDpd24m': 0,
#    'numTl30dpd': 0,
#    'numTl120dpd2m': 0,
#    'numIlTl': 1,
#    'moSinOldIlAcct': 42,
#    'numActvRevTl': 4,
#    'moSinOldRevTlOp': 130,
#    'moSinRcntRevTlOp': 3,
#    'totalRevHiLim': 13700,
#    'numRevTlBalGt0': 5,
#    'numOpRevTl': 6,
#    'totCollAmt': 0,
#    'applicationType': 'INDIVIDUAL',
#    'annualIncJoint': None,
#    'dtiJoint': None,
#    'isIncVJoint': None,
#    'openAcc6m': 1,
#    'openIl12m': 0,
#    'openIl24m': 0,
#    'mthsSinceRcntIl': 42,
#    'totalBalIl': 1662.0,
#    'iLUtil': 12.4,
#    'openRv12m': 3,
#    'openRv24m': 6,
#    'maxBalBc': 3535.0,
#    'allUtil': 41.3,
#    'inqFi': 0,
#    'totalCuTl': 0,
#    'inqLast12m': 4,
#    'mtgPayment': 415.0,
#    'housingPayment': None,
#    'secAppFicoRangeLow': None,
#    'secAppFicoRangeHigh': None,
#    'secAppEarliestCrLine': None,
#    'secAppInqLast6Mths': None,
#    'secAppMortAcc': None,
#    'secAppOpenAcc': None,
#    'secAppRevolUtil': None,
#    'secAppNumRevAccts': None,
#    'secAppChargeoffWithin12Mths': None,
#    'secAppCollections12MthsExMed': None,
#    'secAppMthsSinceLastMajorDerog': None,
#    'revolBalJoint': None,
#    'disbursementMethod': 'DIRECT_PAY',
#    'openActIl': 1,
#    'secAppOpenActIl': None},
#   {'id': 143340126,
#    'memberId': 167230605,
#    'loanAmount': 18000.0,
#    'fundedAmount': 17075.0,
#    'term': 60,
#    'intRate': 10.33,
#    'expDefaultRate': 4.84,
#    'serviceFeeRate': 0.71,
#    'installment': 385.38,
#    'grade': 'B',
#    'subGrade': 'B1',
#    'empLength': 48,
#    'homeOwnership': 'MORTGAGE',
#    'annualInc': 58000.0,
#    'isIncV': 'NOT_VERIFIED',
#    'acceptD': '2018-11-18T19:33:06.000-08:00',
#    'expD': '2018-12-19T10:00:00.000-08:00',
#    'listD': '2018-11-19T10:00:00.000-08:00',
#    'creditPullD': '2018-11-08T15:55:37.000-08:00',
#    'reviewStatusD': '2018-11-19T08:44:09.000-08:00',
#    'reviewStatus': 'APPROVED',
#    'desc': None,
#    'purpose': 'credit_card',
#    'addrZip': '018xx',
#    'addrState': 'MA',
#    'investorCount': None,
#    'ilsExpD': '2018-11-19T10:00:00.000-08:00',
#    'initialListStatus': 'F',
#    'empTitle': 'BILLING MANAGER',
#    'accNowDelinq': 0,
#    'accOpenPast24Mths': 3,
#    'bcOpenToBuy': 18033,
#    'percentBcGt75': 75.0,
#    'bcUtil': 57.7,
#    'dti': 16.39,
#    'delinq2Yrs': 0,
#    'delinqAmnt': 0.0,
#    'earliestCrLine': '2001-10-07T17:00:00.000-07:00',
#    'ficoRangeLow': 705,
#    'ficoRangeHigh': 709,
#    'inqLast6Mths': 0,
#    'mthsSinceLastDelinq': None,
#    'mthsSinceLastRecord': None,
#    'mthsSinceRecentInq': None,
#    'mthsSinceRecentRevolDelinq': None,
#    'mthsSinceRecentBc': 7,
#    'mortAcc': 2,
#    'openAcc': 6,
#    'pubRec': 0,
#    'totalBalExMort': 34876,
#    'revolBal': 24567.0,
#    'revolUtil': 57.7,
#    'totalBcLimit': 42600,
#    'totalAcc': 12,
#    'totalIlHighCreditLimit': 14892,
#    'numRevAccts': 6,
#    'mthsSinceRecentBcDlq': None,
#    'pubRecBankruptcies': 0,
#    'numAcctsEver120Ppd': 0,
#    'chargeoffWithin12Mths': 0,
#    'collections12MthsExMed': 0,
#    'taxLiens': 0,
#    'mthsSinceLastMajorDerog': None,
#    'numSats': 6,
#    'numTlOpPast12m': 2,
#    'moSinRcntTl': 7,
#    'totHiCredLim': 207745,
#    'totCurBal': 178569,
#    'avgCurBal': 29762,
#    'numBcTl': 4,
#    'numActvBcTl': 4,
#    'numBcSats': 4,
#    'pctTlNvrDlq': 100,
#    'numTl90gDpd24m': 0,
#    'numTl30dpd': 0,
#    'numTl120dpd2m': 0,
#    'numIlTl': 4,
#    'moSinOldIlAcct': 205,
#    'numActvRevTl': 4,
#    'moSinOldRevTlOp': 134,
#    'moSinRcntRevTlOp': 7,
#    'totalRevHiLim': 42600,
#    'numRevTlBalGt0': 4,
#    'numOpRevTl': 4,
#    'totCollAmt': 0,
#    'applicationType': 'INDIVIDUAL',
#    'annualIncJoint': None,
#    'dtiJoint': None,
#    'isIncVJoint': None,
#    'openAcc6m': 0,
#    'openIl12m': 1,
#    'openIl24m': 1,
#    'mthsSinceRcntIl': 12,
#    'totalBalIl': 10309.0,
#    'iLUtil': 69.2,
#    'openRv12m': 1,
#    'openRv24m': 2,
#    'maxBalBc': 8624.0,
#    'allUtil': 60.7,
#    'inqFi': 0,
#    'totalCuTl': 0,
#    'inqLast12m': 0,
#    'mtgPayment': 916.88,
#    'housingPayment': None,
#    'secAppFicoRangeLow': None,
#    'secAppFicoRangeHigh': None,
#    'secAppEarliestCrLine': None,
#    'secAppInqLast6Mths': None,
#    'secAppMortAcc': None,
#    'secAppOpenAcc': None,
#    'secAppRevolUtil': None,
#    'secAppNumRevAccts': None,
#    'secAppChargeoffWithin12Mths': None,
#    'secAppCollections12MthsExMed': None,
#    'secAppMthsSinceLastMajorDerog': None,
#    'revolBalJoint': None,
#    'disbursementMethod': 'DIRECT_PAY',
#    'openActIl': 1,
#    'secAppOpenActIl': None},
#   {'id': 142550266,
#    'memberId': 165541317,
#    'loanAmount': 5000.0,
#    'fundedAmount': 2875.0,
#    'term': 36,
#    'intRate': 12.73,
#    'expDefaultRate': 3.94,
#    'serviceFeeRate': 0.97,
#    'installment': 167.83,
#    'grade': 'B',
#    'subGrade': 'B5',
#    'empLength': None,
#    'homeOwnership': 'OWN',
#    'annualInc': 11000.0,
#    'isIncV': 'NOT_VERIFIED',
#    'acceptD': '2018-11-19T08:06:27.000-08:00',
#    'expD': '2018-12-19T10:00:00.000-08:00',
#    'listD': '2018-11-19T10:00:00.000-08:00',
#    'creditPullD': '2018-10-23T20:15:20.000-07:00',
#    'reviewStatusD': '2018-11-19T08:34:02.000-08:00',
#    'reviewStatus': 'APPROVED',
#    'desc': None,
#    'purpose': 'debt_consolidation',
#    'addrZip': '400xx',
#    'addrState': 'KY',
#    'investorCount': None,
#    'ilsExpD': '2018-11-19T10:00:00.000-08:00',
#    'initialListStatus': 'F',
#    'empTitle': None,
#    'accNowDelinq': 0,
#    'accOpenPast24Mths': 3,
#    'bcOpenToBuy': 5650,
#    'percentBcGt75': 0.0,
#    'bcUtil': 5.8,
#    'dti': 10.04,
#    'delinq2Yrs': 0,
#    'delinqAmnt': 0.0,
#    'earliestCrLine': '1999-10-23T17:00:00.000-07:00',
#    'ficoRangeLow': 690,
#    'ficoRangeHigh': 694,
#    'inqLast6Mths': 3,
#    'mthsSinceLastDelinq': None,
#    'mthsSinceLastRecord': 91,
#    'mthsSinceRecentInq': 2,
#    'mthsSinceRecentRevolDelinq': None,
#    'mthsSinceRecentBc': 6,
#    'mortAcc': 0,
#    'openAcc': 3,
#    'pubRec': 1,
#    'totalBalExMort': 826,
#    'revolBal': 826.0,
#    'revolUtil': 7.9,
#    'totalBcLimit': 6000,
#    'totalAcc': 7,
#    'totalIlHighCreditLimit': 0,
#    'numRevAccts': 4,
#    'mthsSinceRecentBcDlq': None,
#    'pubRecBankruptcies': 1,
#    'numAcctsEver120Ppd': 0,
#    'chargeoffWithin12Mths': 0,
#    'collections12MthsExMed': 0,
#    'taxLiens': 0,
#    'mthsSinceLastMajorDerog': None,
#    'numSats': 3,
#    'numTlOpPast12m': 3,
#    'moSinRcntTl': 2,
#    'totHiCredLim': 10500,
#    'totCurBal': 826,
#    'avgCurBal': 275,
#    'numBcTl': 2,
#    'numActvBcTl': 1,
#    'numBcSats': 1,
#    'pctTlNvrDlq': 100,
#    'numTl90gDpd24m': 0,
#    'numTl30dpd': 0,
#    'numTl120dpd2m': 0,
#    'numIlTl': 3,
#    'moSinOldIlAcct': 134,
#    'numActvRevTl': 3,
#    'moSinOldRevTlOp': 228,
#    'moSinRcntRevTlOp': 2,
#    'totalRevHiLim': 10500,
#    'numRevTlBalGt0': 3,
#    'numOpRevTl': 3,
#    'totCollAmt': 585,
#    'applicationType': 'INDIVIDUAL',
#    'annualIncJoint': None,
#    'dtiJoint': None,
#    'isIncVJoint': None,
#    'openAcc6m': 2,
#    'openIl12m': 0,
#    'openIl24m': 0,
#    'mthsSinceRcntIl': 108,
#    'totalBalIl': 0.0,
#    'iLUtil': None,
#    'openRv12m': 3,
#    'openRv24m': 3,
#    'maxBalBc': 350.0,
#    'allUtil': 7.9,
#    'inqFi': 1,
#    'totalCuTl': 1,
#    'inqLast12m': 3,
#    'mtgPayment': 0.0,
#    'housingPayment': None,
#    'secAppFicoRangeLow': None,
#    'secAppFicoRangeHigh': None,
#    'secAppEarliestCrLine': None,
#    'secAppInqLast6Mths': None,
#    'secAppMortAcc': None,
#    'secAppOpenAcc': None,
#    'secAppRevolUtil': None,
#    'secAppNumRevAccts': None,
#    'secAppChargeoffWithin12Mths': None,
#    'secAppCollections12MthsExMed': None,
#    'secAppMthsSinceLastMajorDerog': None,
#    'revolBalJoint': None,
#    'disbursementMethod': 'CASH',
#    'openActIl': 0,
#    'secAppOpenActIl': None},
#   {'id': 143547015,
#    'memberId': 167583775,
#    'loanAmount': 12000.0,
#    'fundedAmount': 9250.0,
#    'term': 36,
#    'intRate': 8.81,
#    'expDefaultRate': 1.8,
#    'serviceFeeRate': 0.84,
#    'installment': 380.54,
#    'grade': 'A',
#    'subGrade': 'A5',
#    'empLength': 24,
#    'homeOwnership': 'MORTGAGE',
#    'annualInc': 175000.0,
#    'isIncV': 'NOT_VERIFIED',
#    'acceptD': '2018-11-16T15:10:06.000-08:00',
#    'expD': '2018-12-19T10:00:00.000-08:00',
#    'listD': '2018-11-19T10:00:00.000-08:00',
#    'creditPullD': '2018-11-13T20:12:03.000-08:00',
#    'reviewStatusD': '2018-11-19T07:29:16.000-08:00',
#    'reviewStatus': 'APPROVED',
#    'desc': None,
#    'purpose': 'debt_consolidation',
#    'addrZip': '935xx',
#    'addrState': 'CA',
#    'investorCount': None,
#    'ilsExpD': '2018-11-19T10:00:00.000-08:00',
#    'initialListStatus': 'F',
#    'empTitle': 'Manager',
#    'accNowDelinq': 0,
#    'accOpenPast24Mths': 4,
#    'bcOpenToBuy': 24771,
#    'percentBcGt75': 0.0,
#    'bcUtil': 32.3,
#    'dti': 10.19,
#    'delinq2Yrs': 0,
#    'delinqAmnt': 0.0,
#    'earliestCrLine': '1989-06-13T17:00:00.000-07:00',
#    'ficoRangeLow': 740,
#    'ficoRangeHigh': 744,
#    'inqLast6Mths': 0,
#    'mthsSinceLastDelinq': None,
#    'mthsSinceLastRecord': 103,
#    'mthsSinceRecentInq': 11,
#    'mthsSinceRecentRevolDelinq': None,
#    'mthsSinceRecentBc': 7,
#    'mortAcc': 0,
#    'openAcc': 12,
#    'pubRec': 1,
#    'totalBalExMort': 53068,
#    'revolBal': 11859.0,
#    'revolUtil': 23.8,
#    'totalBcLimit': 36600,
#    'totalAcc': 14,
#    'totalIlHighCreditLimit': 52955,
#    'numRevAccts': 12,
#    'mthsSinceRecentBcDlq': None,
#    'pubRecBankruptcies': 1,
#    'numAcctsEver120Ppd': 0,
#    'chargeoffWithin12Mths': 0,
#    'collections12MthsExMed': 0,
#    'taxLiens': 0,
#    'mthsSinceLastMajorDerog': None,
#    'numSats': 12,
#    'numTlOpPast12m': 2,
#    'moSinRcntTl': 7,
#    'totHiCredLim': 102755,
#    'totCurBal': 53068,
#    'avgCurBal': 4422,
#    'numBcTl': 5,
#    'numActvBcTl': 4,
#    'numBcSats': 5,
#    'pctTlNvrDlq': 100,
#    'numTl90gDpd24m': 0,
#    'numTl30dpd': 0,
#    'numTl120dpd2m': 0,
#    'numIlTl': 2,
#    'moSinOldIlAcct': 18,
#    'numActvRevTl': 5,
#    'moSinOldRevTlOp': 353,
#    'moSinRcntRevTlOp': 7,
#    'totalRevHiLim': 49800,
#    'numRevTlBalGt0': 5,
#    'numOpRevTl': 10,
#    'totCollAmt': 0,
#    'applicationType': 'INDIVIDUAL',
#    'annualIncJoint': None,
#    'dtiJoint': None,
#    'isIncVJoint': None,
#    'openAcc6m': 0,
#    'openIl12m': 1,
#    'openIl24m': 2,
#    'mthsSinceRcntIl': 11,
#    'totalBalIl': 41209.0,
#    'iLUtil': 77.5,
#    'openRv12m': 1,
#    'openRv24m': 2,
#    'maxBalBc': 7835.0,
#    'allUtil': 36.2,
#    'inqFi': 2,
#    'totalCuTl': 0,
#    'inqLast12m': 1,
#    'mtgPayment': 0.0,
#    'housingPayment': None,
#    'secAppFicoRangeLow': None,
#    'secAppFicoRangeHigh': None,
#    'secAppEarliestCrLine': None,
#    'secAppInqLast6Mths': None,
#    'secAppMortAcc': None,
#    'secAppOpenAcc': None,
#    'secAppRevolUtil': None,
#    'secAppNumRevAccts': None,
#    'secAppChargeoffWithin12Mths': None,
#    'secAppCollections12MthsExMed': None,
#    'secAppMthsSinceLastMajorDerog': None,
#    'revolBalJoint': None,
#    'disbursementMethod': 'CASH',
#    'openActIl': 2,
#    'secAppOpenActIl': None},
#   {'id': 143715113,
#    'memberId': 167995825,
#    'loanAmount': 6025.0,
#    'fundedAmount': 2225.0,
#    'term': 36,
#    'intRate': 10.33,
#    'expDefaultRate': 4.53,
#    'serviceFeeRate': 0.99,
#    'installment': 195.35,
#    'grade': 'B',
#    'subGrade': 'B1',
#    'empLength': None,
#    'homeOwnership': 'RENT',
#    'annualInc': 20000.0,
#    'isIncV': 'VERIFIED',
#    'acceptD': '2018-11-16T10:58:26.000-08:00',
#    'expD': '2018-12-19T10:00:00.000-08:00',
#    'listD': '2018-11-19T10:00:00.000-08:00',
#    'creditPullD': '2018-11-16T10:54:52.000-08:00',
#    'reviewStatusD': '2018-11-19T08:34:46.000-08:00',
#    'reviewStatus': 'APPROVED',
#    'desc': None,
#    'purpose': 'debt_consolidation',
#    'addrZip': '010xx',
#    'addrState': 'MA',
#    'investorCount': None,
#    'ilsExpD': '2018-11-19T10:00:00.000-08:00',
#    'initialListStatus': 'F',
#    'empTitle': None,
#    'accNowDelinq': 0,
#    'accOpenPast24Mths': 2,
#    'bcOpenToBuy': 6666,
#    'percentBcGt75': 0.0,
#    'bcUtil': 38.3,
#    'dti': 9.06,
#    'delinq2Yrs': 0,
#    'delinqAmnt': 0.0,
#    'earliestCrLine': '1997-12-15T16:00:00.000-08:00',
#    'ficoRangeLow': 705,
#    'ficoRangeHigh': 709,
#    'inqLast6Mths': 1,
#    'mthsSinceLastDelinq': 29,
#    'mthsSinceLastRecord': 85,
#    'mthsSinceRecentInq': 2,
#    'mthsSinceRecentRevolDelinq': None,
#    'mthsSinceRecentBc': 31,
#    'mortAcc': 0,
#    'openAcc': 5,
#    'pubRec': 1,
#    'totalBalExMort': 4180,
#    'revolBal': 4180.0,
#    'revolUtil': 22.1,
#    'totalBcLimit': 10800,
#    'totalAcc': 18,
#    'totalIlHighCreditLimit': 0,
#    'numRevAccts': 15,
#    'mthsSinceRecentBcDlq': None,
#    'pubRecBankruptcies': 1,
#    'numAcctsEver120Ppd': 1,
#    'chargeoffWithin12Mths': 0,
#    'collections12MthsExMed': 0,
#    'taxLiens': 0,
#    'mthsSinceLastMajorDerog': 29,
#    'numSats': 5,
#    'numTlOpPast12m': 0,
#    'moSinRcntTl': 23,
#    'totHiCredLim': 18900,
#    'totCurBal': 4180,
#    'avgCurBal': 836,
#    'numBcTl': 9,
#    'numActvBcTl': 2,
#    'numBcSats': 2,
#    'pctTlNvrDlq': 94,
#    'numTl90gDpd24m': 0,
#    'numTl30dpd': 0,
#    'numTl120dpd2m': 0,
#    'numIlTl': 2,
#    'moSinOldIlAcct': 134,
#    'numActvRevTl': 3,
#    'moSinOldRevTlOp': 160,
#    'moSinRcntRevTlOp': 23,
#    'totalRevHiLim': 18900,
#    'numRevTlBalGt0': 3,
#    'numOpRevTl': 5,
#    'totCollAmt': 0,
#    'applicationType': 'INDIVIDUAL',
#    'annualIncJoint': None,
#    'dtiJoint': None,
#    'isIncVJoint': None,
#    'openAcc6m': 0,
#    'openIl12m': 0,
#    'openIl24m': 0,
#    'mthsSinceRcntIl': 59,
#    'totalBalIl': 0.0,
#    'iLUtil': None,
#    'openRv12m': 0,
#    'openRv24m': 2,
#    'maxBalBc': 2097.0,
#    'allUtil': 22.1,
#    'inqFi': 0,
#    'totalCuTl': 0,
#    'inqLast12m': 1,
#    'mtgPayment': 0.0,
#    'housingPayment': 450.0,
#    'secAppFicoRangeLow': None,
#    'secAppFicoRangeHigh': None,
#    'secAppEarliestCrLine': None,
#    'secAppInqLast6Mths': None,
#    'secAppMortAcc': None,
#    'secAppOpenAcc': None,
#    'secAppRevolUtil': None,
#    'secAppNumRevAccts': None,
#    'secAppChargeoffWithin12Mths': None,
#    'secAppCollections12MthsExMed': None,
#    'secAppMthsSinceLastMajorDerog': None,
#    'revolBalJoint': None,
#    'disbursementMethod': 'CASH',
#    'openActIl': 0,
#    'secAppOpenActIl': None},
#   {'id': 143845667,
#    'memberId': 168327756,
#    'loanAmount': 11100.0,
#    'fundedAmount': 5775.0,
#    'term': 36,
#    'intRate': 23.4,
#    'expDefaultRate': 15.49,
#    'serviceFeeRate': 1.62,
#    'installment': 432.0,
#    'grade': 'E',
#    'subGrade': 'E1',
#    'empLength': 48,
#    'homeOwnership': 'MORTGAGE',
#    'annualInc': 76000.0,
#    'isIncV': 'SOURCE_VERIFIED',
#    'acceptD': '2018-11-18T23:30:34.000-08:00',
#    'expD': '2018-12-19T10:00:00.000-08:00',
#    'listD': '2018-11-19T10:00:00.000-08:00',
#    'creditPullD': '2018-11-18T23:09:38.000-08:00',
#    'reviewStatusD': '2018-11-19T07:26:43.000-08:00',
#    'reviewStatus': 'APPROVED',
#    'desc': None,
#    'purpose': 'debt_consolidation',
#    'addrZip': '922xx',
#    'addrState': 'CA',
#    'investorCount': None,
#    'ilsExpD': '2018-11-19T10:00:00.000-08:00',
#    'initialListStatus': 'F',
#    'empTitle': 'General Manager ',
#    'accNowDelinq': 0,
#    'accOpenPast24Mths': 2,
#    'bcOpenToBuy': 12619,
#    'percentBcGt75': 25.0,
#    'bcUtil': 32.9,
#    'dti': 23.8,
#    'delinq2Yrs': 1,
#    'delinqAmnt': 0.0,
#    'earliestCrLine': '2011-02-18T16:00:00.000-08:00',
#    'ficoRangeLow': 670,
#    'ficoRangeHigh': 674,
#    'inqLast6Mths': 2,
#    'mthsSinceLastDelinq': 19,
#    'mthsSinceLastRecord': None,
#    'mthsSinceRecentInq': 1,
#    'mthsSinceRecentRevolDelinq': None,
#    'mthsSinceRecentBc': 31,
#    'mortAcc': 1,
#    'openAcc': 7,
#    'pubRec': 0,
#    'totalBalExMort': 50313,
#    'revolBal': 6181.0,
#    'revolUtil': 32.9,
#    'totalBcLimit': 18800,
#    'totalAcc': 8,
#    'totalIlHighCreditLimit': 68650,
#    'numRevAccts': 4,
#    'mthsSinceRecentBcDlq': None,
#    'pubRecBankruptcies': 0,
#    'numAcctsEver120Ppd': 0,
#    'chargeoffWithin12Mths': 0,
#    'collections12MthsExMed': 0,
#    'taxLiens': 0,
#    'mthsSinceLastMajorDerog': None,
#    'numSats': 7,
#    'numTlOpPast12m': 2,
#    'moSinRcntTl': 8,
#    'totHiCredLim': 213550,
#    'totCurBal': 175088,
#    'avgCurBal': 25013,
#    'numBcTl': 4,
#    'numActvBcTl': 4,
#    'numBcSats': 4,
#    'pctTlNvrDlq': 100,
#    'numTl90gDpd24m': 0,
#    'numTl30dpd': 0,
#    'numTl120dpd2m': 0,
#    'numIlTl': 3,
#    'moSinOldIlAcct': 65,
#    'numActvRevTl': 4,
#    'moSinOldRevTlOp': 93,
#    'moSinRcntRevTlOp': 31,
#    'totalRevHiLim': 18800,
#    'numRevTlBalGt0': 4,
#    'numOpRevTl': 4,
#    'totCollAmt': 684,
#    'applicationType': 'INDIVIDUAL',
#    'annualIncJoint': None,
#    'dtiJoint': None,
#    'isIncVJoint': None,
#    'openAcc6m': 0,
#    'openIl12m': 1,
#    'openIl24m': 1,
#    'mthsSinceRcntIl': 8,
#    'totalBalIl': 44132.0,
#    'iLUtil': 89.9,
#    'openRv12m': 0,
#    'openRv24m': 0,
#    'maxBalBc': 6122.0,
#    'allUtil': 68.8,
#    'inqFi': 1,
#    'totalCuTl': 0,
#    'inqLast12m': 6,
#    'mtgPayment': 1046.9,
#    'housingPayment': None,
#    'secAppFicoRangeLow': None,
#    'secAppFicoRangeHigh': None,
#    'secAppEarliestCrLine': None,
#    'secAppInqLast6Mths': None,
#    'secAppMortAcc': None,
#    'secAppOpenAcc': None,
#    'secAppRevolUtil': None,
#    'secAppNumRevAccts': None,
#    'secAppChargeoffWithin12Mths': None,
#    'secAppCollections12MthsExMed': None,
#    'secAppMthsSinceLastMajorDerog': None,
#    'revolBalJoint': None,
#    'disbursementMethod': 'DIRECT_PAY',
#    'openActIl': 2,
#    'secAppOpenActIl': None},
#   {'id': 143816583,
#    'memberId': 168277573,
#    'loanAmount': 13500.0,
#    'fundedAmount': 7375.0,
#    'term': 36,
#    'intRate': 11.31,
#    'expDefaultRate': 4.53,
#    'serviceFeeRate': 0.99,
#    'installment': 443.96,
#    'grade': 'B',
#    'subGrade': 'B3',
#    'empLength': 24,
#    'homeOwnership': 'OWN',
#    'annualInc': 50800.0,
#    'isIncV': 'SOURCE_VERIFIED',
#    'acceptD': '2018-11-18T08:54:44.000-08:00',
#    'expD': '2018-12-19T10:00:00.000-08:00',
#    'listD': '2018-11-19T10:00:00.000-08:00',
#    'creditPullD': '2018-11-18T08:14:27.000-08:00',
#    'reviewStatusD': '2018-11-19T08:46:23.000-08:00',
#    'reviewStatus': 'APPROVED',
#    'desc': None,
#    'purpose': 'credit_card',
#    'addrZip': '913xx',
#    'addrState': 'CA',
#    'investorCount': None,
#    'ilsExpD': '2018-11-19T10:00:00.000-08:00',
#    'initialListStatus': 'F',
#    'empTitle': 'manager',
#    'accNowDelinq': 0,
#    'accOpenPast24Mths': 2,
#    'bcOpenToBuy': 7435,
#    'percentBcGt75': 0.0,
#    'bcUtil': 31.8,
#    'dti': 15.5,
#    'delinq2Yrs': 0,
#    'delinqAmnt': 0.0,
#    'earliestCrLine': '2011-08-17T17:00:00.000-07:00',
#    'ficoRangeLow': 735,
#    'ficoRangeHigh': 739,
#    'inqLast6Mths': 3,
#    'mthsSinceLastDelinq': None,
#    'mthsSinceLastRecord': None,
#    'mthsSinceRecentInq': 0,
#    'mthsSinceRecentRevolDelinq': None,
#    'mthsSinceRecentBc': 12,
#    'mortAcc': 0,
#    'openAcc': 7,
#    'pubRec': 0,
#    'totalBalExMort': 21822,
#    'revolBal': 3465.0,
#    'revolUtil': 27.3,
#    'totalBcLimit': 10900,
#    'totalAcc': 9,
#    'totalIlHighCreditLimit': 27167,
#    'numRevAccts': 6,
#    'mthsSinceRecentBcDlq': None,
#    'pubRecBankruptcies': 0,
#    'numAcctsEver120Ppd': 0,
#    'chargeoffWithin12Mths': 0,
#    'collections12MthsExMed': 0,
#    'taxLiens': 0,
#    'mthsSinceLastMajorDerog': None,
#    'numSats': 7,
#    'numTlOpPast12m': 1,
#    'moSinRcntTl': 12,
#    'totHiCredLim': 39867,
#    'totCurBal': 21822,
#    'avgCurBal': 3117,
#    'numBcTl': 3,
#    'numActvBcTl': 3,
#    'numBcSats': 3,
#    'pctTlNvrDlq': 100,
#    'numTl90gDpd24m': 0,
#    'numTl30dpd': 0,
#    'numTl120dpd2m': 0,
#    'numIlTl': 3,
#    'moSinOldIlAcct': 67,
#    'numActvRevTl': 3,
#    'moSinOldRevTlOp': 87,
#    'moSinRcntRevTlOp': 12,
#    'totalRevHiLim': 12700,
#    'numRevTlBalGt0': 3,
#    'numOpRevTl': 5,
#    'totCollAmt': 0,
#    'applicationType': 'INDIVIDUAL',
#    'annualIncJoint': None,
#    'dtiJoint': None,
#    'isIncVJoint': None,
#    'openAcc6m': 0,
#    'openIl12m': 0,
#    'openIl24m': 1,
#    'mthsSinceRcntIl': 20,
#    'totalBalIl': 18357.0,
#    'iLUtil': 67.6,
#    'openRv12m': 1,
#    'openRv24m': 1,
#    'maxBalBc': 1956.0,
#    'allUtil': 54.7,
#    'inqFi': 4,
#    'totalCuTl': 1,
#    'inqLast12m': 14,
#    'mtgPayment': 0.0,
#    'housingPayment': None,
#    'secAppFicoRangeLow': None,
#    'secAppFicoRangeHigh': None,
#    'secAppEarliestCrLine': None,
#    'secAppInqLast6Mths': None,
#    'secAppMortAcc': None,
#    'secAppOpenAcc': None,
#    'secAppRevolUtil': None,
#    'secAppNumRevAccts': None,
#    'secAppChargeoffWithin12Mths': None,
#    'secAppCollections12MthsExMed': None,
#    'secAppMthsSinceLastMajorDerog': None,
#    'revolBalJoint': None,
#    'disbursementMethod': 'CASH',
#    'openActIl': 2,
#    'secAppOpenActIl': None},
#   {'id': 143691303,
#    'memberId': 167946405,
#    'loanAmount': 9625.0,
#    'fundedAmount': 3475.0,
#    'term': 36,
#    'intRate': 10.33,
#    'expDefaultRate': 4.53,
#    'serviceFeeRate': 0.99,
#    'installment': 312.07,
#    'grade': 'B',
#    'subGrade': 'B1',
#    'empLength': 360,
#    'homeOwnership': 'OWN',
#    'annualInc': 75000.0,
#    'isIncV': 'VERIFIED',
#    'acceptD': '2018-11-16T05:35:11.000-08:00',
#    'expD': '2018-12-19T10:00:00.000-08:00',
#    'listD': '2018-11-19T10:00:00.000-08:00',
#    'creditPullD': '2018-11-16T05:07:52.000-08:00',
#    'reviewStatusD': '2018-11-19T09:43:32.000-08:00',
#    'reviewStatus': 'APPROVED',
#    'desc': None,
#    'purpose': 'credit_card',
#    'addrZip': '212xx',
#    'addrState': 'MD',
#    'investorCount': None,
#    'ilsExpD': '2018-11-19T10:00:00.000-08:00',
#    'initialListStatus': 'F',
#    'empTitle': 'Network manager',
#    'accNowDelinq': 0,
#    'accOpenPast24Mths': 8,
#    'bcOpenToBuy': 25216,
#    'percentBcGt75': 30.0,
#    'bcUtil': 41.1,
#    'dti': 54.83,
#    'delinq2Yrs': 0,
#    'delinqAmnt': 0.0,
#    'earliestCrLine': '2008-03-15T17:00:00.000-07:00',
#    'ficoRangeLow': 690,
#    'ficoRangeHigh': 694,
#    'inqLast6Mths': 0,
#    'mthsSinceLastDelinq': None,
#    'mthsSinceLastRecord': 103,
#    'mthsSinceRecentInq': 5,
#    'mthsSinceRecentRevolDelinq': None,
#    'mthsSinceRecentBc': 5,
#    'mortAcc': 0,
#    'openAcc': 30,
#    'pubRec': 1,
#    'totalBalExMort': 133085,
#    'revolBal': 19795.0,
#    'revolUtil': 31.9,
#    'totalBcLimit': 42800,
#    'totalAcc': 45,
#    'totalIlHighCreditLimit': 161658,
#    'numRevAccts': 22,
#    'mthsSinceRecentBcDlq': None,
#    'pubRecBankruptcies': 1,
#    'numAcctsEver120Ppd': 0,
#    'chargeoffWithin12Mths': 0,
#    'collections12MthsExMed': 0,
#    'taxLiens': 0,
#    'mthsSinceLastMajorDerog': None,
#    'numSats': 30,
#    'numTlOpPast12m': 5,
#    'moSinRcntTl': 5,
#    'totHiCredLim': 223658,
#    'totCurBal': 133085,
#    'avgCurBal': 4436,
#    'numBcTl': 12,
#    'numActvBcTl': 5,
#    'numBcSats': 10,
#    'pctTlNvrDlq': 100,
#    'numTl90gDpd24m': 0,
#    'numTl30dpd': 0,
#    'numTl120dpd2m': 0,
#    'numIlTl': 23,
#    'moSinOldIlAcct': 128,
#    'numActvRevTl': 8,
#    'moSinOldRevTlOp': 84,
#    'moSinRcntRevTlOp': 5,
#    'totalRevHiLim': 62000,
#    'numRevTlBalGt0': 8,
#    'numOpRevTl': 18,
#    'totCollAmt': 0,
#    'applicationType': 'JOINT',
#    'annualIncJoint': 147000.0,
#    'dtiJoint': 38.36,
#    'isIncVJoint': 'VERIFIED',
#    'openAcc6m': 1,
#    'openIl12m': 2,
#    'openIl24m': 3,
#    'mthsSinceRcntIl': 9,
#    'totalBalIl': 113290.0,
#    'iLUtil': 70.1,
#    'openRv12m': 3,
#    'openRv24m': 5,
#    'maxBalBc': 5690.0,
#    'allUtil': 59.5,
#    'inqFi': 4,
#    'totalCuTl': 9,
#    'inqLast12m': 3,
#    'mtgPayment': 0.0,
#    'housingPayment': None,
#    'secAppFicoRangeLow': 660,
#    'secAppFicoRangeHigh': 664,
#    'secAppEarliestCrLine': '1993-12-15T16:00:00.000-08:00',
#    'secAppInqLast6Mths': 1,
#    'secAppMortAcc': 0,
#    'secAppOpenAcc': 32,
#    'secAppRevolUtil': 59.9,
#    'secAppNumRevAccts': 38,
#    'secAppChargeoffWithin12Mths': 0,
#    'secAppCollections12MthsExMed': 0,
#    'secAppMthsSinceLastMajorDerog': None,
#    'revolBalJoint': 83420,
#    'disbursementMethod': 'CASH',
#    'openActIl': 12,
#    'secAppOpenActIl': 7},
#   {'id': 143794072,
#    'memberId': 168277037,
#    'loanAmount': 25000.0,
#    'fundedAmount': 18775.0,
#    'term': 60,
#    'intRate': 15.02,
#    'expDefaultRate': 6.95,
#    'serviceFeeRate': 0.83,
#    'installment': 595.02,
#    'grade': 'C',
#    'subGrade': 'C3',
#    'empLength': 108,
#    'homeOwnership': 'OWN',
#    'annualInc': 123000.0,
#    'isIncV': 'SOURCE_VERIFIED',
#    'acceptD': '2018-11-18T18:11:10.000-08:00',
#    'expD': '2018-12-19T10:00:00.000-08:00',
#    'listD': '2018-11-19T10:00:00.000-08:00',
#    'creditPullD': '2018-11-18T00:17:55.000-08:00',
#    'reviewStatusD': '2018-11-19T06:42:35.000-08:00',
#    'reviewStatus': 'APPROVED',
#    'desc': None,
#    'purpose': 'credit_card',
#    'addrZip': '995xx',
#    'addrState': 'AK',
#    'investorCount': None,
#    'ilsExpD': '2018-11-19T10:00:00.000-08:00',
#    'initialListStatus': 'F',
#    'empTitle': 'GENERAL MANAGER',
#    'accNowDelinq': 0,
#    'accOpenPast24Mths': 7,
#    'bcOpenToBuy': 7024,
#    'percentBcGt75': 66.7,
#    'bcUtil': 68.1,
#    'dti': 33.49,
#    'delinq2Yrs': 0,
#    'delinqAmnt': 0.0,
#    'earliestCrLine': '1994-08-17T17:00:00.000-07:00',
#    'ficoRangeLow': 695,
#    'ficoRangeHigh': 699,
#    'inqLast6Mths': 0,
#    'mthsSinceLastDelinq': 34,
#    'mthsSinceLastRecord': None,
#    'mthsSinceRecentInq': 17,
#    'mthsSinceRecentRevolDelinq': 65,
#    'mthsSinceRecentBc': 2,
#    'mortAcc': 1,
#    'openAcc': 12,
#    'pubRec': 0,
#    'totalBalExMort': 103513,
#    'revolBal': 22697.0,
#    'revolUtil': 67.4,
#    'totalBcLimit': 22000,
#    'totalAcc': 33,
#    'totalIlHighCreditLimit': 110734,
#    'numRevAccts': 12,
#    'mthsSinceRecentBcDlq': 65,
#    'pubRecBankruptcies': 0,
#    'numAcctsEver120Ppd': 0,
#    'chargeoffWithin12Mths': 0,
#    'collections12MthsExMed': 0,
#    'taxLiens': 0,
#    'mthsSinceLastMajorDerog': None,
#    'numSats': 12,
#    'numTlOpPast12m': 4,
#    'moSinRcntTl': 2,
#    'totHiCredLim': 144434,
#    'totCurBal': 103513,
#    'avgCurBal': 8626,
#    'numBcTl': 6,
#    'numActvBcTl': 3,
#    'numBcSats': 3,
#    'pctTlNvrDlq': 92,
#    'numTl90gDpd24m': 0,
#    'numTl30dpd': 0,
#    'numTl120dpd2m': 0,
#    'numIlTl': 20,
#    'moSinOldIlAcct': 291,
#    'numActvRevTl': 6,
#    'moSinOldRevTlOp': 162,
#    'moSinRcntRevTlOp': 2,
#    'totalRevHiLim': 33700,
#    'numRevTlBalGt0': 6,
#    'numOpRevTl': 6,
#    'totCollAmt': 1159,
#    'applicationType': 'INDIVIDUAL',
#    'annualIncJoint': None,
#    'dtiJoint': None,
#    'isIncVJoint': None,
#    'openAcc6m': 3,
#    'openIl12m': 1,
#    'openIl24m': 4,
#    'mthsSinceRcntIl': 3,
#    'totalBalIl': 80816.0,
#    'iLUtil': 52.7,
#    'openRv12m': 3,
#    'openRv24m': 3,
#    'maxBalBc': 6740.0,
#    'allUtil': 57.8,
#    'inqFi': 3,
#    'totalCuTl': 8,
#    'inqLast12m': 0,
#    'mtgPayment': 0.0,
#    'housingPayment': None,
#    'secAppFicoRangeLow': None,
#    'secAppFicoRangeHigh': None,
#    'secAppEarliestCrLine': None,
#    'secAppInqLast6Mths': None,
#    'secAppMortAcc': None,
#    'secAppOpenAcc': None,
#    'secAppRevolUtil': None,
#    'secAppNumRevAccts': None,
#    'secAppChargeoffWithin12Mths': None,
#    'secAppCollections12MthsExMed': None,
#    'secAppMthsSinceLastMajorDerog': None,
#    'revolBalJoint': None,
#    'disbursementMethod': 'CASH',
#    'openActIl': 6,
#    'secAppOpenActIl': None},
#   {'id': 143854725,
#    'memberId': 168347887,
#    'loanAmount': 11000.0,
#    'fundedAmount': 3175.0,
#    'term': 36,
#    'intRate': 15.02,
#    'expDefaultRate': 7.25,
#    'serviceFeeRate': 1.16,
#    'installment': 381.43,
#    'grade': 'C',
#    'subGrade': 'C3',
#    'empLength': None,
#    'homeOwnership': 'OWN',
#    'annualInc': 48000.0,
#    'isIncV': 'SOURCE_VERIFIED',
#    'acceptD': '2018-11-19T08:18:07.000-08:00',
#    'expD': '2018-12-19T10:00:00.000-08:00',
#    'listD': '2018-11-19T10:00:00.000-08:00',
#    'creditPullD': '2018-11-19T08:11:13.000-08:00',
#    'reviewStatusD': '2018-11-19T08:48:11.000-08:00',
#    'reviewStatus': 'APPROVED',
#    'desc': None,
#    'purpose': 'debt_consolidation',
#    'addrZip': '282xx',
#    'addrState': 'NC',
#    'investorCount': None,
#    'ilsExpD': '2018-11-19T10:00:00.000-08:00',
#    'initialListStatus': 'F',
#    'empTitle': None,
#    'accNowDelinq': 0,
#    'accOpenPast24Mths': 6,
#    'bcOpenToBuy': 18306,
#    'percentBcGt75': 0.0,
#    'bcUtil': 25.3,
#    'dti': 12.73,
#    'delinq2Yrs': 0,
#    'delinqAmnt': 0.0,
#    'earliestCrLine': '1998-04-18T17:00:00.000-07:00',
#    'ficoRangeLow': 690,
#    'ficoRangeHigh': 694,
#    'inqLast6Mths': 0,
#    'mthsSinceLastDelinq': 39,
#    'mthsSinceLastRecord': None,
#    'mthsSinceRecentInq': 12,
#    'mthsSinceRecentRevolDelinq': 39,
#    'mthsSinceRecentBc': 4,
#    'mortAcc': 0,
#    'openAcc': 11,
#    'pubRec': 0,
#    'totalBalExMort': 13159,
#    'revolBal': 13159.0,
#    'revolUtil': 34.6,
#    'totalBcLimit': 24500,
#    'totalAcc': 14,
#    'totalIlHighCreditLimit': 0,
#    'numRevAccts': 13,
#    'mthsSinceRecentBcDlq': None,
#    'pubRecBankruptcies': 0,
#    'numAcctsEver120Ppd': 0,
#    'chargeoffWithin12Mths': 0,
#    'collections12MthsExMed': 0,
#    'taxLiens': 0,
#    'mthsSinceLastMajorDerog': None,
#    'numSats': 11,
#    'numTlOpPast12m': 4,
#    'moSinRcntTl': 4,
#    'totHiCredLim': 38000,
#    'totCurBal': 13159,
#    'avgCurBal': 1196,
#    'numBcTl': 4,
#    'numActvBcTl': 3,
#    'numBcSats': 4,
#    'pctTlNvrDlq': 85,
#    'numTl90gDpd24m': 0,
#    'numTl30dpd': 0,
#    'numTl120dpd2m': 0,
#    'numIlTl': 1,
#    'moSinOldIlAcct': 138,
#    'numActvRevTl': 8,
#    'moSinOldRevTlOp': 247,
#    'moSinRcntRevTlOp': 4,
#    'totalRevHiLim': 38000,
#    'numRevTlBalGt0': 8,
#    'numOpRevTl': 11,
#    'totCollAmt': 0,
#    'applicationType': 'INDIVIDUAL',
#    'annualIncJoint': None,
#    'dtiJoint': None,
#    'isIncVJoint': None,
#    'openAcc6m': 1,
#    'openIl12m': 0,
#    'openIl24m': 0,
#    'mthsSinceRcntIl': 138,
#    'totalBalIl': 0.0,
#    'iLUtil': None,
#    'openRv12m': 4,
#    'openRv24m': 6,
#    'maxBalBc': 3467.0,
#    'allUtil': 34.6,
#    'inqFi': 0,
#    'totalCuTl': 1,
#    'inqLast12m': 1,
#    'mtgPayment': 0.0,
#    'housingPayment': None,
#    'secAppFicoRangeLow': None,
#    'secAppFicoRangeHigh': None,
#    'secAppEarliestCrLine': None,
#    'secAppInqLast6Mths': None,
#    'secAppMortAcc': None,
#    'secAppOpenAcc': None,
#    'secAppRevolUtil': None,
#    'secAppNumRevAccts': None,
#    'secAppChargeoffWithin12Mths': None,
#    'secAppCollections12MthsExMed': None,
#    'secAppMthsSinceLastMajorDerog': None,
#    'revolBalJoint': None,
#    'disbursementMethod': 'CASH',
#    'openActIl': 0,
#    'secAppOpenActIl': None},
#   {'id': 143852664,
#    'memberId': 168346846,
#    'loanAmount': 16800.0,
#    'fundedAmount': 8900.0,
#    'term': 36,
#    'intRate': 11.31,
#    'expDefaultRate': 4.53,
#    'serviceFeeRate': 0.99,
#    'installment': 552.49,
#    'grade': 'B',
#    'subGrade': 'B3',
#    'empLength': 252,
#    'homeOwnership': 'MORTGAGE',
#    'annualInc': 65000.0,
#    'isIncV': 'NOT_VERIFIED',
#    'acceptD': '2018-11-19T08:07:38.000-08:00',
#    'expD': '2018-12-19T10:00:00.000-08:00',
#    'listD': '2018-11-19T10:00:00.000-08:00',
#    'creditPullD': '2018-11-19T08:05:28.000-08:00',
#    'reviewStatusD': '2018-11-19T08:08:34.000-08:00',
#    'reviewStatus': 'APPROVED',
#    'desc': None,
#    'purpose': 'credit_card',
#    'addrZip': '484xx',
#    'addrState': 'MI',
#    'investorCount': None,
#    'ilsExpD': '2018-11-19T10:00:00.000-08:00',
#    'initialListStatus': 'F',
#    'empTitle': 'Finance Admin Asst',
#    'accNowDelinq': 0,
#    'accOpenPast24Mths': 2,
#    'bcOpenToBuy': 3122,
#    'percentBcGt75': 100.0,
#    'bcUtil': 88.4,
#    'dti': 27.73,
#    'delinq2Yrs': 0,
#    'delinqAmnt': 0.0,
#    'earliestCrLine': '1999-10-18T17:00:00.000-07:00',
#    'ficoRangeLow': 685,
#    'ficoRangeHigh': 689,
#    'inqLast6Mths': 0,
#    'mthsSinceLastDelinq': None,
#    'mthsSinceLastRecord': 110,
#    'mthsSinceRecentInq': 9,
#    'mthsSinceRecentRevolDelinq': None,
#    'mthsSinceRecentBc': 41,
#    'mortAcc': 2,
#    'openAcc': 14,
#    'pubRec': 1,
#    'totalBalExMort': 44535,
#    'revolBal': 28423.0,
#    'revolUtil': 75.8,
#    'totalBcLimit': 26800,
#    'totalAcc': 30,
#    'totalIlHighCreditLimit': 34980,
#    'numRevAccts': 14,
#    'mthsSinceRecentBcDlq': None,
#    'pubRecBankruptcies': 1,
#    'numAcctsEver120Ppd': 0,
#    'chargeoffWithin12Mths': 0,
#    'collections12MthsExMed': 0,
#    'taxLiens': 0,
#    'mthsSinceLastMajorDerog': None,
#    'numSats': 14,
#    'numTlOpPast12m': 1,
#    'moSinRcntTl': 9,
#    'totHiCredLim': 251560,
#    'totCurBal': 215395,
#    'avgCurBal': 16569,
#    'numBcTl': 5,
#    'numActvBcTl': 5,
#    'numBcSats': 5,
#    'pctTlNvrDlq': 100,
#    'numTl90gDpd24m': 0,
#    'numTl30dpd': 0,
#    'numTl120dpd2m': 0,
#    'numIlTl': 14,
#    'moSinOldIlAcct': 175,
#    'numActvRevTl': 8,
#    'moSinOldRevTlOp': 229,
#    'moSinRcntRevTlOp': 9,
#    'totalRevHiLim': 37500,
#    'numRevTlBalGt0': 8,
#    'numOpRevTl': 11,
#    'totCollAmt': 0,
#    'applicationType': 'INDIVIDUAL',
#    'annualIncJoint': None,
#    'dtiJoint': None,
#    'isIncVJoint': None,
#    'openAcc6m': 0,
#    'openIl12m': 0,
#    'openIl24m': 1,
#    'mthsSinceRcntIl': 15,
#    'totalBalIl': 16112.0,
#    'iLUtil': 46.1,
#    'openRv12m': 1,
#    'openRv24m': 1,
#    'maxBalBc': 8901.0,
#    'allUtil': 61.4,
#    'inqFi': 1,
#    'totalCuTl': 1,
#    'inqLast12m': 1,
#    'mtgPayment': 1339.0,
#    'housingPayment': None,
#    'secAppFicoRangeLow': None,
#    'secAppFicoRangeHigh': None,
#    'secAppEarliestCrLine': None,
#    'secAppInqLast6Mths': None,
#    'secAppMortAcc': None,
#    'secAppOpenAcc': None,
#    'secAppRevolUtil': None,
#    'secAppNumRevAccts': None,
#    'secAppChargeoffWithin12Mths': None,
#    'secAppCollections12MthsExMed': None,
#    'secAppMthsSinceLastMajorDerog': None,
#    'revolBalJoint': None,
#    'disbursementMethod': 'CASH',
#    'openActIl': 2,
#    'secAppOpenActIl': None},
#   {'id': 143596928,
#    'memberId': 167645933,
#    'loanAmount': 25000.0,
#    'fundedAmount': 16875.0,
#    'term': 36,
#    'intRate': 27.27,
#    'expDefaultRate': 15.49,
#    'serviceFeeRate': 1.62,
#    'installment': 1024.26,
#    'grade': 'E',
#    'subGrade': 'E5',
#    'empLength': 120,
#    'homeOwnership': 'MORTGAGE',
#    'annualInc': 79000.0,
#    'isIncV': 'NOT_VERIFIED',
#    'acceptD': '2018-11-16T12:53:38.000-08:00',
#    'expD': '2018-12-19T10:00:00.000-08:00',
#    'listD': '2018-11-19T10:00:00.000-08:00',
#    'creditPullD': '2018-11-14T13:32:44.000-08:00',
#    'reviewStatusD': '2018-11-19T08:31:50.000-08:00',
#    'reviewStatus': 'APPROVED',
#    'desc': None,
#    'purpose': 'debt_consolidation',
#    'addrZip': '809xx',
#    'addrState': 'CO',
#    'investorCount': None,
#    'ilsExpD': '2018-11-19T10:00:00.000-08:00',
#    'initialListStatus': 'F',
#    'empTitle': ' key account manager ',
#    'accNowDelinq': 0,
#    'accOpenPast24Mths': 4,
#    'bcOpenToBuy': 10626,
#    'percentBcGt75': 25.0,
#    'bcUtil': 66.4,
#    'dti': 16.57,
#    'delinq2Yrs': 0,
#    'delinqAmnt': 0.0,
#    'earliestCrLine': '2005-02-13T16:00:00.000-08:00',
#    'ficoRangeLow': 670,
#    'ficoRangeHigh': 674,
#    'inqLast6Mths': 1,
#    'mthsSinceLastDelinq': 46,
#    'mthsSinceLastRecord': None,
#    'mthsSinceRecentInq': 4,
#    'mthsSinceRecentRevolDelinq': None,
#    'mthsSinceRecentBc': 11,
#    'mortAcc': 1,
#    'openAcc': 10,
#    'pubRec': 0,
#    'totalBalExMort': 42120,
#    'revolBal': 24278.0,
#    'revolUtil': 60.4,
#    'totalBcLimit': 30600,
#    'totalAcc': 15,
#    'totalIlHighCreditLimit': 30214,
#    'numRevAccts': 10,
#    'mthsSinceRecentBcDlq': None,
#    'pubRecBankruptcies': 0,
#    'numAcctsEver120Ppd': 0,
#    'chargeoffWithin12Mths': 0,
#    'collections12MthsExMed': 0,
#    'taxLiens': 0,
#    'mthsSinceLastMajorDerog': None,
#    'numSats': 10,
#    'numTlOpPast12m': 4,
#    'moSinRcntTl': 4,
#    'totHiCredLim': 381614,
#    'totCurBal': 352378,
#    'avgCurBal': 35238,
#    'numBcTl': 4,
#    'numActvBcTl': 4,
#    'numBcSats': 4,
#    'pctTlNvrDlq': 92,
#    'numTl90gDpd24m': 0,
#    'numTl30dpd': 0,
#    'numTl120dpd2m': 0,
#    'numIlTl': 4,
#    'moSinOldIlAcct': 142,
#    'numActvRevTl': 7,
#    'moSinOldRevTlOp': 165,
#    'moSinRcntRevTlOp': 4,
#    'totalRevHiLim': 39800,
#    'numRevTlBalGt0': 7,
#    'numOpRevTl': 8,
#    'totCollAmt': 0,
#    'applicationType': 'INDIVIDUAL',
#    'annualIncJoint': None,
#    'dtiJoint': None,
#    'isIncVJoint': None,
#    'openAcc6m': 2,
#    'openIl12m': 0,
#    'openIl24m': 0,
#    'mthsSinceRcntIl': 27,
#    'totalBalIl': 17842.0,
#    'iLUtil': 59.1,
#    'openRv12m': 3,
#    'openRv24m': 3,
#    'maxBalBc': 8978.0,
#    'allUtil': 59.7,
#    'inqFi': 0,
#    'totalCuTl': 3,
#    'inqLast12m': 5,
#    'mtgPayment': 2258.74,
#    'housingPayment': 2200.0,
#    'secAppFicoRangeLow': None,
#    'secAppFicoRangeHigh': None,
#    'secAppEarliestCrLine': None,
#    'secAppInqLast6Mths': None,
#    'secAppMortAcc': None,
#    'secAppOpenAcc': None,
#    'secAppRevolUtil': None,
#    'secAppNumRevAccts': None,
#    'secAppChargeoffWithin12Mths': None,
#    'secAppCollections12MthsExMed': None,
#    'secAppMthsSinceLastMajorDerog': None,
#    'revolBalJoint': None,
#    'disbursementMethod': 'DIRECT_PAY',
#    'openActIl': 1,
#    'secAppOpenActIl': None},
#   {'id': 143811741,
#    'memberId': 168308848,
#    'loanAmount': 20000.0,
#    'fundedAmount': 8550.0,
#    'term': 60,
#    'intRate': 25.34,
#    'expDefaultRate': 16.15,
#    'serviceFeeRate': 1.28,
#    'installment': 591.02,
#    'grade': 'E',
#    'subGrade': 'E3',
#    'empLength': None,
#    'homeOwnership': 'RENT',
#    'annualInc': 65000.0,
#    'isIncV': 'NOT_VERIFIED',
#    'acceptD': '2018-11-18T08:25:58.000-08:00',
#    'expD': '2018-12-19T10:00:00.000-08:00',
#    'listD': '2018-11-19T10:00:00.000-08:00',
#    'creditPullD': '2018-11-18T08:21:01.000-08:00',
#    'reviewStatusD': '2018-11-19T08:15:29.000-08:00',
#    'reviewStatus': 'APPROVED',
#    'desc': None,
#    'purpose': 'debt_consolidation',
#    'addrZip': '334xx',
#    'addrState': 'FL',
#    'investorCount': None,
#    'ilsExpD': '2018-11-19T10:00:00.000-08:00',
#    'initialListStatus': 'F',
#    'empTitle': None,
#    'accNowDelinq': 0,
#    'accOpenPast24Mths': 3,
#    'bcOpenToBuy': 11829,
#    'percentBcGt75': 0.0,
#    'bcUtil': 35.4,
#    'dti': 10.8,
#    'delinq2Yrs': 0,
# ...
#    'secAppRevolUtil': 52.5,
#    'secAppNumRevAccts': 3,
#    'secAppChargeoffWithin12Mths': 0,
#    'secAppCollections12MthsExMed': 0,
#    'secAppMthsSinceLastMajorDerog': None,
#    'revolBalJoint': 90733,
#    'disbursementMethod': 'CASH',
#    'openActIl': 2,
#    'secAppOpenActIl': 6},
#   {'id': 143855431,
#    'memberId': 168336574,
#    'loanAmount': 15000.0,
#    'fundedAmount': 3150.0,
#    'term': 36,
#    'intRate': 16.14,
#    'expDefaultRate': 7.25,
#    'serviceFeeRate': 1.16,
#    'installment': 528.4,
#    'grade': 'C',
#    'subGrade': 'C4',
#    'empLength': None,
#    'homeOwnership': 'RENT',
#    'annualInc': 165000.0,
#    'isIncV': 'NOT_VERIFIED',
#    'acceptD': '2018-11-19T07:11:34.000-08:00',
#    'expD': '2018-12-19T10:00:00.000-08:00',
#    'listD': '2018-11-19T10:00:00.000-08:00',
#    'creditPullD': '2018-11-19T07:11:03.000-08:00',
#    'reviewStatusD': '2018-11-19T07:16:59.000-08:00',
#    'reviewStatus': 'APPROVED',
#    'desc': None,
#    'purpose': 'vacation',
#    'addrZip': '926xx',
#    'addrState': 'CA',
#    'investorCount': None,
#    'ilsExpD': '2018-11-19T10:00:00.000-08:00',
#    'initialListStatus': 'F',
#    'empTitle': None,
#    'accNowDelinq': 0,
#    'accOpenPast24Mths': 9,
#    'bcOpenToBuy': 24209,
#    'percentBcGt75': 44.4,
#    'bcUtil': 48.3,
#    'dti': 19.67,
#    'delinq2Yrs': 0,
#    'delinqAmnt': 0.0,
#    'earliestCrLine': '2010-01-18T16:00:00.000-08:00',
#    'ficoRangeLow': 700,
#    'ficoRangeHigh': 704,
#    'inqLast6Mths': 0,
#    'mthsSinceLastDelinq': None,
#    'mthsSinceLastRecord': None,
#    'mthsSinceRecentInq': 12,
#    'mthsSinceRecentRevolDelinq': None,
#    'mthsSinceRecentBc': 3,
#    'mortAcc': 1,
#    'openAcc': 18,
#    'pubRec': 0,
#    'totalBalExMort': 46747,
#    'revolBal': 22591.0,
#    'revolUtil': 42.9,
#    'totalBcLimit': 46800,
#    'totalAcc': 26,
#    'totalIlHighCreditLimit': 54476,
#    'numRevAccts': 20,
#    'mthsSinceRecentBcDlq': None,
#    'pubRecBankruptcies': 0,
#    'numAcctsEver120Ppd': 0,
#    'chargeoffWithin12Mths': 0,
#    'collections12MthsExMed': 0,
#    'taxLiens': 0,
#    'mthsSinceLastMajorDerog': None,
#    'numSats': 18,
#    'numTlOpPast12m': 6,
#    'moSinRcntTl': 3,
#    'totHiCredLim': 287076,
#    'totCurBal': 191350,
#    'avgCurBal': 10631,
#    'numBcTl': 10,
#    'numActvBcTl': 8,
#    'numBcSats': 9,
#    'pctTlNvrDlq': 100,
#    'numTl90gDpd24m': 0,
#    'numTl30dpd': 0,
#    'numTl120dpd2m': 0,
#    'numIlTl': 5,
#    'moSinOldIlAcct': 36,
#    'numActvRevTl': 8,
#    'moSinOldRevTlOp': 106,
#    'moSinRcntRevTlOp': 3,
#    'totalRevHiLim': 52600,
#    'numRevTlBalGt0': 8,
#    'numOpRevTl': 12,
#    'totCollAmt': 0,
#    'applicationType': 'INDIVIDUAL',
#    'annualIncJoint': None,
#    'dtiJoint': None,
#    'isIncVJoint': None,
#    'openAcc6m': 3,
#    'openIl12m': 1,
#    'openIl24m': 3,
#    'mthsSinceRcntIl': 12,
#    'totalBalIl': 24156.0,
#    'iLUtil': 44.3,
#    'openRv12m': 5,
#    'openRv24m': 6,
#    'maxBalBc': 5391.0,
#    'allUtil': 43.7,
#    'inqFi': 2,
#    'totalCuTl': 1,
#    'inqLast12m': 1,
#    'mtgPayment': 1579.88,
#    'housingPayment': None,
#    'secAppFicoRangeLow': None,
#    'secAppFicoRangeHigh': None,
#    'secAppEarliestCrLine': None,
#    'secAppInqLast6Mths': None,
#    'secAppMortAcc': None,
#    'secAppOpenAcc': None,
#    'secAppRevolUtil': None,
#    'secAppNumRevAccts': None,
#    'secAppChargeoffWithin12Mths': None,
#    'secAppCollections12MthsExMed': None,
#    'secAppMthsSinceLastMajorDerog': None,
#    'revolBalJoint': None,
#    'disbursementMethod': 'CASH',
#    'openActIl': 5,
#    'secAppOpenActIl': None},
#   {'id': 143664778,
#    'memberId': 167865729,
#    'loanAmount': 28000.0,
#    'fundedAmount': 6900.0,
#    'term': 36,
#    'intRate': 8.81,
#    'expDefaultRate': 1.8,
#    'serviceFeeRate': 0.84,
#    'installment': 887.92,
#    'grade': 'A',
#    'subGrade': 'A5',
#    'empLength': 36,
#    'homeOwnership': 'MORTGAGE',
#    'annualInc': 105000.0,
#    'isIncV': 'NOT_VERIFIED',
#    'acceptD': '2018-11-19T07:22:42.000-08:00',
#    'expD': '2018-12-19T10:00:00.000-08:00',
#    'listD': '2018-11-19T10:00:00.000-08:00',
#    'creditPullD': '2018-11-15T14:50:12.000-08:00',
#    'reviewStatusD': '2018-11-19T07:46:45.000-08:00',
#    'reviewStatus': 'APPROVED',
#    'desc': None,
#    'purpose': 'home_improvement',
#    'addrZip': '760xx',
#    'addrState': 'TX',
#    'investorCount': None,
#    'ilsExpD': '2018-11-19T10:00:00.000-08:00',
#    'initialListStatus': 'F',
#    'empTitle': 'IT Project Manager',
#    'accNowDelinq': 0,
#    'accOpenPast24Mths': 5,
#    'bcOpenToBuy': 1168,
#    'percentBcGt75': 100.0,
#    'bcUtil': 94.2,
#    'dti': 20.71,
#    'delinq2Yrs': 0,
#    'delinqAmnt': 0.0,
#    'earliestCrLine': '2004-08-14T17:00:00.000-07:00',
#    'ficoRangeLow': 725,
#    'ficoRangeHigh': 729,
#    'inqLast6Mths': 0,
#    'mthsSinceLastDelinq': None,
#    'mthsSinceLastRecord': None,
#    'mthsSinceRecentInq': 6,
#    'mthsSinceRecentRevolDelinq': None,
#    'mthsSinceRecentBc': 16,
#    'mortAcc': 5,
#    'openAcc': 6,
#    'pubRec': 0,
#    'totalBalExMort': 79856,
#    'revolBal': 22203.0,
#    'revolUtil': 63.4,
#    'totalBcLimit': 20000,
#    'totalAcc': 11,
#    'totalIlHighCreditLimit': 74015,
#    'numRevAccts': 2,
#    'mthsSinceRecentBcDlq': None,
#    'pubRecBankruptcies': 0,
#    'numAcctsEver120Ppd': 0,
#    'chargeoffWithin12Mths': 0,
#    'collections12MthsExMed': 0,
#    'taxLiens': 0,
#    'mthsSinceLastMajorDerog': None,
#    'numSats': 6,
#    'numTlOpPast12m': 2,
#    'moSinRcntTl': 6,
#    'totHiCredLim': 522475,
#    'totCurBal': 490858,
#    'avgCurBal': 81810,
#    'numBcTl': 1,
#    'numActvBcTl': 1,
#    'numBcSats': 1,
#    'pctTlNvrDlq': 100,
#    'numTl90gDpd24m': 0,
#    'numTl30dpd': 0,
#    'numTl120dpd2m': 0,
#    'numIlTl': 4,
#    'moSinOldIlAcct': 171,
#    'numActvRevTl': 2,
#    'moSinOldRevTlOp': 31,
#    'moSinRcntRevTlOp': 16,
#    'totalRevHiLim': 35000,
#    'numRevTlBalGt0': 2,
#    'numOpRevTl': 2,
#    'totCollAmt': 0,
#    'applicationType': 'JOINT',
#    'annualIncJoint': 206000.0,
#    'dtiJoint': 15.4,
#    'isIncVJoint': 'NOT_VERIFIED',
#    'openAcc6m': 2,
#    'openIl12m': 0,
#    'openIl24m': 2,
#    'mthsSinceRcntIl': 17,
#    'totalBalIl': 57653.0,
#    'iLUtil': None,
#    'openRv12m': 0,
#    'openRv24m': 1,
#    'maxBalBc': 18832.0,
#    'allUtil': 63.4,
#    'inqFi': 1,
#    'totalCuTl': 2,
#    'inqLast12m': 2,
#    'mtgPayment': 3553.5,
#    'housingPayment': None,
#    'secAppFicoRangeLow': 700,
#    'secAppFicoRangeHigh': 704,
#    'secAppEarliestCrLine': '1999-07-14T17:00:00.000-07:00',
#    'secAppInqLast6Mths': 0,
#    'secAppMortAcc': 5,
#    'secAppOpenAcc': 12,
#    'secAppRevolUtil': 63.9,
#    'secAppNumRevAccts': 14,
#    'secAppChargeoffWithin12Mths': 0,
#    'secAppCollections12MthsExMed': 0,
#    'secAppMthsSinceLastMajorDerog': None,
#    'revolBalJoint': 42063,
#    'disbursementMethod': 'CASH',
#    'openActIl': 2,
#    'secAppOpenActIl': 3},
#   {'id': 143842515,
#    'memberId': 168323614,
#    'loanAmount': 24000.0,
#    'fundedAmount': 2500.0,
#    'term': 36,
#    'intRate': 23.4,
#    'expDefaultRate': 15.49,
#    'serviceFeeRate': 1.62,
#    'installment': 934.05,
#    'grade': 'E',
#    'subGrade': 'E1',
#    'empLength': 36,
#    'homeOwnership': 'MORTGAGE',
#    'annualInc': 24856.0,
#    'isIncV': 'VERIFIED',
#    'acceptD': '2018-11-18T20:48:34.000-08:00',
#    'expD': '2018-12-19T10:00:00.000-08:00',
#    'listD': '2018-11-19T10:00:00.000-08:00',
#    'creditPullD': '2018-11-18T20:37:36.000-08:00',
#    'reviewStatusD': '2018-11-19T07:25:08.000-08:00',
#    'reviewStatus': 'APPROVED',
#    'desc': None,
#    'purpose': 'debt_consolidation',
#    'addrZip': '960xx',
#    'addrState': 'CA',
#    'investorCount': None,
#    'ilsExpD': '2018-11-19T10:00:00.000-08:00',
#    'initialListStatus': 'F',
#    'empTitle': 'Shipment processor ',
#    'accNowDelinq': 0,
#    'accOpenPast24Mths': 4,
#    'bcOpenToBuy': 7292,
#    'percentBcGt75': 60.0,
#    'bcUtil': 43.0,
#    'dti': 42.3,
#    'delinq2Yrs': 0,
#    'delinqAmnt': 0.0,
#    'earliestCrLine': '2005-05-18T17:00:00.000-07:00',
#    'ficoRangeLow': 670,
#    'ficoRangeHigh': 674,
#    'inqLast6Mths': 0,
#    'mthsSinceLastDelinq': None,
#    'mthsSinceLastRecord': None,
#    'mthsSinceRecentInq': 23,
#    'mthsSinceRecentRevolDelinq': None,
#    'mthsSinceRecentBc': 10,
#    'mortAcc': 2,
#    'openAcc': 19,
#    'pubRec': 0,
#    'totalBalExMort': 22004,
#    'revolBal': 22004.0,
#    'revolUtil': 63.2,
#    'totalBcLimit': 12800,
#    'totalAcc': 23,
#    'totalIlHighCreditLimit': 0,
#    'numRevAccts': 18,
#    'mthsSinceRecentBcDlq': None,
#    'pubRecBankruptcies': 0,
#    'numAcctsEver120Ppd': 0,
#    'chargeoffWithin12Mths': 0,
#    'collections12MthsExMed': 0,
#    'taxLiens': 0,
#    'mthsSinceLastMajorDerog': None,
#    'numSats': 19,
#    'numTlOpPast12m': 3,
#    'moSinRcntTl': 4,
#    'totHiCredLim': 109800,
#    'totCurBal': 46378,
#    'avgCurBal': 2441,
#    'numBcTl': 5,
#    'numActvBcTl': 5,
#    'numBcSats': 5,
#    'pctTlNvrDlq': 100,
#    'numTl90gDpd24m': 0,
#    'numTl30dpd': 0,
#    'numTl120dpd2m': 0,
#    'numIlTl': 3,
#    'moSinOldIlAcct': 161,
#    'numActvRevTl': 16,
#    'moSinOldRevTlOp': 48,
#    'moSinRcntRevTlOp': 4,
#    'totalRevHiLim': 34800,
#    'numRevTlBalGt0': 16,
#    'numOpRevTl': 18,
#    'totCollAmt': 0,
#    'applicationType': 'JOINT',
#    'annualIncJoint': 70616.0,
#    'dtiJoint': 37.32,
#    'isIncVJoint': 'VERIFIED',
#    'openAcc6m': 2,
#    'openIl12m': 0,
#    'openIl24m': 0,
#    'mthsSinceRcntIl': 96,
#    'totalBalIl': 0.0,
#    'iLUtil': None,
#    'openRv12m': 3,
#    'openRv24m': 4,
#    'maxBalBc': 2448.0,
#    'allUtil': 63.2,
#    'inqFi': 0,
#    'totalCuTl': 0,
#    'inqLast12m': 0,
#    'mtgPayment': 509.02,
#    'housingPayment': None,
#    'secAppFicoRangeLow': 670,
#    'secAppFicoRangeHigh': 674,
#    'secAppEarliestCrLine': '2005-05-18T17:00:00.000-07:00',
#    'secAppInqLast6Mths': 0,
#    'secAppMortAcc': 2,
#    'secAppOpenAcc': 17,
#    'secAppRevolUtil': 68.7,
#    'secAppNumRevAccts': 15,
#    'secAppChargeoffWithin12Mths': 0,
#    'secAppCollections12MthsExMed': 0,
#    'secAppMthsSinceLastMajorDerog': None,
#    'revolBalJoint': 44001,
#    'disbursementMethod': 'CASH',
#    'openActIl': 0,
#    'secAppOpenActIl': 3},
#   {'id': 143437750,
#    'memberId': 167440691,
#    'loanAmount': 40000.0,
#    'fundedAmount': 10675.0,
#    'term': 36,
#    'intRate': 6.46,
#    'expDefaultRate': 1.8,
#    'serviceFeeRate': 0.84,
#    'installment': 1225.24,
#    'grade': 'A',
#    'subGrade': 'A1',
#    'empLength': 360,
#    'homeOwnership': 'MORTGAGE',
#    'annualInc': 80000.0,
#    'isIncV': 'SOURCE_VERIFIED',
#    'acceptD': '2018-11-16T09:19:42.000-08:00',
#    'expD': '2018-12-19T10:00:00.000-08:00',
#    'listD': '2018-11-19T10:00:00.000-08:00',
#    'creditPullD': '2018-11-11T11:36:03.000-08:00',
#    'reviewStatusD': '2018-11-19T08:10:22.000-08:00',
#    'reviewStatus': 'APPROVED',
#    'desc': None,
#    'purpose': 'debt_consolidation',
#    'addrZip': '064xx',
#    'addrState': 'CT',
#    'investorCount': None,
#    'ilsExpD': '2018-11-19T10:00:00.000-08:00',
#    'initialListStatus': 'F',
#    'empTitle': 'Const manager',
#    'accNowDelinq': 0,
#    'accOpenPast24Mths': 1,
#    'bcOpenToBuy': 28345,
#    'percentBcGt75': 0.0,
#    'bcUtil': 23.0,
#    'dti': 6.32,
#    'delinq2Yrs': 0,
#    'delinqAmnt': 0.0,
#    'earliestCrLine': '1988-11-10T16:00:00.000-08:00',
#    'ficoRangeLow': 815,
#    'ficoRangeHigh': 819,
#    'inqLast6Mths': 0,
#    'mthsSinceLastDelinq': None,
#    'mthsSinceLastRecord': None,
#    'mthsSinceRecentInq': 1,
#    'mthsSinceRecentRevolDelinq': None,
#    'mthsSinceRecentBc': 34,
#    'mortAcc': 7,
#    'openAcc': 7,
#    'pubRec': 0,
#    'totalBalExMort': 16988,
#    'revolBal': 9243.0,
#    'revolUtil': 19.1,
#    'totalBcLimit': 36800,
#    'totalAcc': 23,
#    'totalIlHighCreditLimit': 10442,
#    'numRevAccts': 13,
#    'mthsSinceRecentBcDlq': None,
#    'pubRecBankruptcies': 0,
#    'numAcctsEver120Ppd': 0,
#    'chargeoffWithin12Mths': 0,
#    'collections12MthsExMed': 0,
#    'taxLiens': 0,
#    'mthsSinceLastMajorDerog': None,
#    'numSats': 7,
#    'numTlOpPast12m': 0,
#    'moSinRcntTl': 18,
#    'totHiCredLim': 240342,
#    'totCurBal': 176292,
#    'avgCurBal': 25185,
#    'numBcTl': 8,
#    'numActvBcTl': 2,
#    'numBcSats': 3,
#    'pctTlNvrDlq': 100,
#    'numTl90gDpd24m': 0,
#    'numTl30dpd': 0,
#    'numTl120dpd2m': 0,
#    'numIlTl': 3,
#    'moSinOldIlAcct': 89,
#    'numActvRevTl': 3,
#    'moSinOldRevTlOp': 360,
#    'moSinRcntRevTlOp': 34,
#    'totalRevHiLim': 48400,
#    'numRevTlBalGt0': 3,
#    'numOpRevTl': 5,
#    'totCollAmt': 0,
#    'applicationType': 'INDIVIDUAL',
#    'annualIncJoint': None,
#    'dtiJoint': None,
#    'isIncVJoint': None,
#    'openAcc6m': 0,
#    'openIl12m': 0,
#    'openIl24m': 1,
#    'mthsSinceRcntIl': 18,
#    'totalBalIl': 7745.0,
#    'iLUtil': 74.2,
#    'openRv12m': 0,
#    'openRv24m': 0,
#    'maxBalBc': 8448.0,
#    'allUtil': 28.9,
#    'inqFi': 2,
#    'totalCuTl': 0,
#    'inqLast12m': 3,
#    'mtgPayment': 1732.0,
#    'housingPayment': None,
#    'secAppFicoRangeLow': None,
#    'secAppFicoRangeHigh': None,
#    'secAppEarliestCrLine': None,
#    'secAppInqLast6Mths': None,
#    'secAppMortAcc': None,
#    'secAppOpenAcc': None,
#    'secAppRevolUtil': None,
#    'secAppNumRevAccts': None,
#    'secAppChargeoffWithin12Mths': None,
#    'secAppCollections12MthsExMed': None,
#    'secAppMthsSinceLastMajorDerog': None,
#    'revolBalJoint': None,
#    'disbursementMethod': 'CASH',
#    'openActIl': 1,
#    'secAppOpenActIl': None},
#   {'id': 143829005,
#    'memberId': 168322082,
#    'loanAmount': 40000.0,
#    'fundedAmount': 4525.0,
#    'term': 36,
#    'intRate': 10.33,
#    'expDefaultRate': 4.53,
#    'serviceFeeRate': 0.99,
#    'installment': 1296.9,
#    'grade': 'B',
#    'subGrade': 'B1',
#    'empLength': 156,
#    'homeOwnership': 'OWN',
#    'annualInc': 85000.0,
#    'isIncV': 'SOURCE_VERIFIED',
#    'acceptD': '2018-11-18T16:43:35.000-08:00',
#    'expD': '2018-12-19T10:00:00.000-08:00',
#    'listD': '2018-11-19T10:00:00.000-08:00',
#    'creditPullD': '2018-11-18T16:30:33.000-08:00',
#    'reviewStatusD': '2018-11-19T07:48:54.000-08:00',
#    'reviewStatus': 'APPROVED',
#    'desc': None,
#    'purpose': 'debt_consolidation',
#    'addrZip': '184xx',
#    'addrState': 'PA',
#    'investorCount': None,
#    'ilsExpD': '2018-11-19T10:00:00.000-08:00',
#    'initialListStatus': 'F',
#    'empTitle': 'Economic Development Specialist',
#    'accNowDelinq': 0,
#    'accOpenPast24Mths': 4,
#    'bcOpenToBuy': 21383,
#    'percentBcGt75': 0.0,
#    'bcUtil': 19.6,
#    'dti': 26.57,
#    'delinq2Yrs': 0,
#    'delinqAmnt': 0.0,
#    'earliestCrLine': '2007-08-18T17:00:00.000-07:00',
#    'ficoRangeLow': 760,
#    'ficoRangeHigh': 764,
#    'inqLast6Mths': 1,
#    'mthsSinceLastDelinq': None,
#    'mthsSinceLastRecord': None,
#    'mthsSinceRecentInq': 3,
#    'mthsSinceRecentRevolDelinq': None,
#    'mthsSinceRecentBc': 20,
#    'mortAcc': 0,
#    'openAcc': 12,
#    'pubRec': 0,
#    'totalBalExMort': 76514,
#    'revolBal': 8375.0,
#    'revolUtil': 18.2,
#    'totalBcLimit': 26600,
#    'totalAcc': 21,
#    'totalIlHighCreditLimit': 88115,
#    'numRevAccts': 11,
#    'mthsSinceRecentBcDlq': None,
#    'pubRecBankruptcies': 0,
#    'numAcctsEver120Ppd': 0,
#    'chargeoffWithin12Mths': 0,
#    'collections12MthsExMed': 0,
#    'taxLiens': 0,
#    'mthsSinceLastMajorDerog': None,
#    'numSats': 12,
#    'numTlOpPast12m': 1,
#    'moSinRcntTl': 3,
#    'totHiCredLim': 134215,
#    'totCurBal': 76514,
#    'avgCurBal': 6376,
#    'numBcTl': 5,
#    'numActvBcTl': 3,
#    'numBcSats': 4,
#    'pctTlNvrDlq': 100,
#    'numTl90gDpd24m': 0,
#    'numTl30dpd': 0,
#    'numTl120dpd2m': 0,
#    'numIlTl': 10,
#    'moSinOldIlAcct': 73,
#    'numActvRevTl': 4,
#    'moSinOldRevTlOp': 135,
#    'moSinRcntRevTlOp': 20,
#    'totalRevHiLim': 46100,
#    'numRevTlBalGt0': 4,
#    'numOpRevTl': 6,
#    'totCollAmt': 0,
#    'applicationType': 'INDIVIDUAL',
#    'annualIncJoint': None,
#    'dtiJoint': None,
#    'isIncVJoint': None,
#    'openAcc6m': 1,
#    'openIl12m': 1,
#    'openIl24m': 3,
#    'mthsSinceRcntIl': 3,
#    'totalBalIl': 68139.0,
#    'iLUtil': 77.3,
#    'openRv12m': 0,
#    'openRv24m': 1,
#    'maxBalBc': 2165.0,
#    'allUtil': 57.0,
#    'inqFi': 1,
#    'totalCuTl': 4,
#    'inqLast12m': 1,
#    'mtgPayment': 0.0,
#    'housingPayment': None,
#    'secAppFicoRangeLow': None,
#    'secAppFicoRangeHigh': None,
#    'secAppEarliestCrLine': None,
#    'secAppInqLast6Mths': None,
#    'secAppMortAcc': None,
#    'secAppOpenAcc': None,
#    'secAppRevolUtil': None,
#    'secAppNumRevAccts': None,
#    'secAppChargeoffWithin12Mths': None,
#    'secAppCollections12MthsExMed': None,
#    'secAppMthsSinceLastMajorDerog': None,
#    'revolBalJoint': None,
#    'disbursementMethod': 'CASH',
#    'openActIl': 6,
#    'secAppOpenActIl': None}]}

# %%
data = r.json()
myData =data['loans']

# %% [markdown]
# ## with open() as

# %%
with open('current_list.txt', 'w') as outfile:
    json.dump(myData, outfile)

# %%
df_current=pd.read_json('current_list.txt')

# %%
# why we only get few loans through api, but there are much more listed on the lending club website?  -- Might because API only 
# gives you the data from the latest update.

df_current.tail()
# Out:
#     accNowDelinq  accOpenPast24Mths                        acceptD addrState  \
# 16             0                  9  2018-11-19T07:11:34.000-08:00        CA
# 17             0                  5  2018-11-19T07:22:42.000-08:00        TX
# 18             0                  4  2018-11-18T20:48:34.000-08:00        CA
# 19             0                  1  2018-11-16T09:19:42.000-08:00        CT
# 20             0                  4  2018-11-18T16:43:35.000-08:00        PA
#
#    addrZip  allUtil  annualInc  annualIncJoint applicationType  avgCurBal  \
# 16   926xx     43.7     165000             NaN      INDIVIDUAL      10631
# 17   760xx     63.4     105000        206000.0           JOINT      81810
# 18   960xx     63.2      24856         70616.0           JOINT       2441
# 19   064xx     28.9      80000             NaN      INDIVIDUAL      25185
# 20   184xx     57.0      85000             NaN      INDIVIDUAL       6376
#
#         ...        totCollAmt  totCurBal  totHiCredLim  totalAcc  \
# 16      ...                 0     191350        287076        26
# 17      ...                 0     490858        522475        11
# 18      ...                 0      46378        109800        23
# 19      ...                 0     176292        240342        23
# 20      ...                 0      76514        134215        21
#
#    totalBalExMort  totalBalIl  totalBcLimit  totalCuTl totalIlHighCreditLimit  \
# 16          46747       24156         46800          1                  54476
# 17          79856       57653         20000          2                  74015
# 18          22004           0         12800          0                      0
# 19          16988        7745         36800          0                  10442
# 20          76514       68139         26600          4                  88115
#
#     totalRevHiLim
# 16          52600
# 17          35000
# 18          34800
# 19          48400
# 20          46100
#
# [5 rows x 119 columns]

# %%
# A better way to read a json file (can read json to data frame with more complex structure)

df_current = pd.io.json.json_normalize(myData)

# %%
df_current.tail()
# Out:
#     accNowDelinq  accOpenPast24Mths                        acceptD addrState  \
# 16             0                  9  2018-11-19T07:11:34.000-08:00        CA
# 17             0                  5  2018-11-19T07:22:42.000-08:00        TX
# 18             0                  4  2018-11-18T20:48:34.000-08:00        CA
# 19             0                  1  2018-11-16T09:19:42.000-08:00        CT
# 20             0                  4  2018-11-18T16:43:35.000-08:00        PA
#
#    addrZip  allUtil  annualInc  annualIncJoint applicationType  avgCurBal  \
# 16   926xx     43.7   165000.0             NaN      INDIVIDUAL      10631
# 17   760xx     63.4   105000.0        206000.0           JOINT      81810
# 18   960xx     63.2    24856.0         70616.0           JOINT       2441
# 19   064xx     28.9    80000.0             NaN      INDIVIDUAL      25185
# 20   184xx     57.0    85000.0             NaN      INDIVIDUAL       6376
#
#         ...        totCollAmt  totCurBal  totHiCredLim  totalAcc  \
# 16      ...                 0     191350        287076        26
# 17      ...                 0     490858        522475        11
# 18      ...                 0      46378        109800        23
# 19      ...                 0     176292        240342        23
# 20      ...                 0      76514        134215        21
#
#    totalBalExMort  totalBalIl  totalBcLimit totalCuTl totalIlHighCreditLimit  \
# 16          46747     24156.0         46800         1                  54476
# 17          79856     57653.0         20000         2                  74015
# 18          22004         0.0         12800         0                      0
# 19          16988      7745.0         36800         0                  10442
# 20          76514     68139.0         26600         4                  88115
#
#     totalRevHiLim
# 16          52600
# 17          35000
# 18          34800
# 19          48400
# 20          46100
#
# [5 rows x 119 columns]

# %% [markdown]
# ## Historical Data

# %%
df_2014 = pd.read_csv('Loan2014_05302017.csv', skiprows=1)

# %%
print df_2014.head()
# Out:
#          id  member_id  loan_amnt  funded_amnt  funded_amnt_inv        term  \
# 0  36805548        NaN    10400.0      10400.0          10400.0   36 months
# 1  38098114        NaN    15000.0      15000.0          15000.0   60 months
# 2  37842129        NaN    21425.0      21425.0          21425.0   60 months
# 3  37662224        NaN     7650.0       7650.0           7650.0   36 months
# 4  37822187        NaN     9600.0       9600.0           9600.0   36 months
#
#   int_rate  installment grade sub_grade                 ...                  \
# 0    6.99%       321.08     A        A3                 ...
# 1   12.39%       336.64     C        C1                 ...
# 2   15.59%       516.36     D        D1                 ...
# 3   13.66%       260.20     C        C3                 ...
# 4   13.66%       326.53     C        C3                 ...
#
#   sec_app_earliest_cr_line sec_app_inq_last_6mths sec_app_mort_acc  \
# 0                      NaN                    NaN              NaN
# 1                      NaN                    NaN              NaN
# 2                      NaN                    NaN              NaN
# 3                      NaN                    NaN              NaN
# 4                      NaN                    NaN              NaN
#
#    sec_app_open_acc sec_app_revol_util sec_app_open_il_6m  \
# 0               NaN                NaN                NaN
# 1               NaN                NaN                NaN
# 2               NaN                NaN                NaN
# 3               NaN                NaN                NaN
# 4               NaN                NaN                NaN
#
#   sec_app_num_rev_accts sec_app_chargeoff_within_12_mths  \
# 0                   NaN                              NaN
# 1                   NaN                              NaN
# 2                   NaN                              NaN
# 3                   NaN                              NaN
# 4                   NaN                              NaN
#
#   sec_app_collections_12_mths_ex_med sec_app_mths_since_last_major_derog
# 0                                NaN                                 NaN
# 1                                NaN                                 NaN
# 2                                NaN                                 NaN
# 3                                NaN                                 NaN
# 4                                NaN                                 NaN
#
# [5 rows x 128 columns]

# %%
df_2014.shape
# Out:
# (235631, 128)

# %%
print '----------current-----------------'
for col in df_current.columns.values:
    print col
print '----------current-----------------'
# Out:
# ----------current-----------------
# accNowDelinq
# accOpenPast24Mths
# acceptD
# addrState
# addrZip
# allUtil
# annualInc
# annualIncJoint
# applicationType
# avgCurBal
# bcOpenToBuy
# bcUtil
# chargeoffWithin12Mths
# collections12MthsExMed
# creditPullD
# delinq2Yrs
# delinqAmnt
# desc
# dti
# dtiJoint
# earliestCrLine
# empLength
# empTitle
# expD
# expDefaultRate
# ficoRangeHigh
# ficoRangeLow
# fundedAmount
# grade
# homeOwnership
# iLUtil
# id
# ilsExpD
# initialListStatus
# inqFi
# inqLast12m
# inqLast6Mths
# installment
# intRate
# investorCount
# isIncV
# isIncVJoint
# listD
# loanAmount
# maxBalBc
# memberId
# moSinOldIlAcct
# moSinOldRevTlOp
# moSinRcntRevTlOp
# moSinRcntTl
# mortAcc
# mthsSinceLastDelinq
# mthsSinceLastMajorDerog
# mthsSinceLastRecord
# mthsSinceRcntIl
# mthsSinceRecentBc
# mthsSinceRecentBcDlq
# mthsSinceRecentInq
# mthsSinceRecentRevolDelinq
# numAcctsEver120Ppd
# numActvBcTl
# numActvRevTl
# numBcSats
# numBcTl
# numIlTl
# numOpRevTl
# numRevAccts
# numRevTlBalGt0
# numSats
# numTl120dpd2m
# numTl30dpd
# numTl90gDpd24m
# numTlOpPast12m
# openAcc
# openAcc6m
# openIl12m
# openIl24m
# openIl6m
# openRv12m
# openRv24m
# pctTlNvrDlq
# percentBcGt75
# pubRec
# pubRecBankruptcies
# purpose
# reviewStatus
# reviewStatusD
# revolBal
# revolUtil
# serviceFeeRate
# subGrade
# taxLiens
# term
# totCollAmt
# totCurBal
# totHiCredLim
# totalAcc
# totalBalExMort
# totalBalIl
# totalBcLimit
# totalCuTl
# totalIlHighCreditLimit
# totalRevHiLim
# ----------current-----------------

# %%
print '----------2014-----------------'
for col in df_2014.columns.values:
    print col
print '----------2014-----------------'
# Out:
# ----------2014-----------------
# id
# member_id
# loan_amnt
# funded_amnt
# funded_amnt_inv
# term
# int_rate
# installment
# grade
# sub_grade
# emp_title
# emp_length
# home_ownership
# annual_inc
# verification_status
# issue_d
# loan_status
# pymnt_plan
# url
# desc
# purpose
# title
# zip_code
# addr_state
# dti
# delinq_2yrs
# earliest_cr_line
# fico_range_low
# fico_range_high
# inq_last_6mths
# mths_since_last_delinq
# mths_since_last_record
# open_acc
# pub_rec
# revol_bal
# revol_util
# total_acc
# initial_list_status
# out_prncp
# out_prncp_inv
# total_pymnt
# total_pymnt_inv
# total_rec_prncp
# total_rec_int
# total_rec_late_fee
# recoveries
# collection_recovery_fee
# last_pymnt_d
# last_pymnt_amnt
# next_pymnt_d
# last_credit_pull_d
# last_fico_range_high
# last_fico_range_low
# collections_12_mths_ex_med
# mths_since_last_major_derog
# policy_code
# application_type
# annual_inc_joint
# dti_joint
# verification_status_joint
# acc_now_delinq
# tot_coll_amt
# tot_cur_bal
# open_acc_6m
# open_il_6m
# open_il_12m
# open_il_24m
# mths_since_rcnt_il
# total_bal_il
# il_util
# open_rv_12m
# open_rv_24m
# max_bal_bc
# all_util
# total_rev_hi_lim
# inq_fi
# total_cu_tl
# inq_last_12m
# acc_open_past_24mths
# avg_cur_bal
# bc_open_to_buy
# bc_util
# chargeoff_within_12_mths
# delinq_amnt
# mo_sin_old_il_acct
# mo_sin_old_rev_tl_op
# mo_sin_rcnt_rev_tl_op
# mo_sin_rcnt_tl
# mort_acc
# mths_since_recent_bc
# mths_since_recent_bc_dlq
# mths_since_recent_inq
# mths_since_recent_revol_delinq
# num_accts_ever_120_pd
# num_actv_bc_tl
# num_actv_rev_tl
# num_bc_sats
# num_bc_tl
# num_il_tl
# num_op_rev_tl
# num_rev_accts
# num_rev_tl_bal_gt_0
# num_sats
# num_tl_120dpd_2m
# num_tl_30dpd
# num_tl_90g_dpd_24m
# num_tl_op_past_12m
# pct_tl_nvr_dlq
# percent_bc_gt_75
# pub_rec_bankruptcies
# tax_liens
# tot_hi_cred_lim
# total_bal_ex_mort
# total_bc_limit
# total_il_high_credit_limit
# revol_bal_joint
# sec_app_fico_range_low
# sec_app_fico_range_high
# sec_app_earliest_cr_line
# sec_app_inq_last_6mths
# sec_app_mort_acc
# sec_app_open_acc
# sec_app_revol_util
# sec_app_open_il_6m
# sec_app_num_rev_accts
# sec_app_chargeoff_within_12_mths
# sec_app_collections_12_mths_ex_med
# sec_app_mths_since_last_major_derog
# ----------2014-----------------

# %% [markdown]
# ## Format conversion of feature names

# %%
current_feature = list(df_current.columns.values)

# %%
for i in range (len(current_feature)):
    current_feature[i] = str.lower(str(current_feature[i]))

# %%
current_feature[:5]
# Out:
# ['accnowdelinq', 'accopenpast24mths', 'acceptd', 'addrstate', 'addrzip']

# %%
his_feature = list(df_2014.columns.values)

# %%
for i in range (len(his_feature)):
    his_feature[i] = str(his_feature[i]).replace('_','')

# %%
his_feature[:5]
# Out:
# ['id', 'memberid', 'loanamnt', 'fundedamnt', 'fundedamntinv']

# %%
common_feature = set(his_feature)&(set(current_feature))
print len(common_feature)
print common_feature
# Out:
# 87
# set(['bcopentobuy', 'numactvbctl', 'mthssincelastrecord', 'totcurbal', 'totalbalexmort', 'subgrade', 'mosinrcnttl', 'ficorangelow', 'mortacc', 'mthssincelastdelinq', 'tothicredlim', 'maxbalbc', 'totalrevhilim', 'numtl120dpd2m', 'annualincjoint', 'earliestcrline', 'inqlast12m', 'totalacc', 'desc', 'term', 'installment', 'numrevaccts', 'avgcurbal', 'openil6m', 'addrstate', 'mosinoldilacct', 'annualinc', 'revolutil', 'numsats', 'mthssincerecentbc', 'mthssincercntil', 'openrv24m', 'chargeoffwithin12mths', 'mosinoldrevtlop', 'taxliens', 'openil12m', 'mthssincerecentinq', 'numiltl', 'totalcutl', 'mthssincelastmajorderog', 'initialliststatus', 'grade', 'numbctl', 'numoprevtl', 'numactvrevtl', 'ficorangehigh', 'openil24m', 'totcollamt', 'memberid', 'applicationtype', 'intrate', 'dti', 'mthssincerecentbcdlq', 'homeownership', 'pubrec', 'accopenpast24mths', 'mthssincerecentrevoldelinq', 'bcutil', 'openacc6m', 'totalbalil', 'delinq2yrs', 'inqfi', 'numtl30dpd', 'dtijoint', 'id', 'revolbal', 'inqlast6mths', 'pcttlnvrdlq', 'openrv12m', 'emptitle', 'totalilhighcreditlimit', 'collections12mthsexmed', 'numtl90gdpd24m', 'delinqamnt', 'percentbcgt75', 'numbcsats', 'totalbclimit', 'accnowdelinq', 'purpose', 'emplength', 'ilutil', 'mosinrcntrevtlop', 'allutil', 'openacc', 'numrevtlbalgt0', 'numtloppast12m', 'pubrecbankruptcies'])

# %%
his_unique=set(his_feature)-set(current_feature)
current_unique=set(current_feature)-set(his_feature)
print len(current_unique), current_unique
print len(his_unique), his_unique
# Out:
# 16 set(['expdefaultrate', 'creditpulld', 'isincvjoint', 'ilsexpd', 'reviewstatus', 'loanamount', 'investorcount', 'isincv', 'servicefeerate', 'addrzip', 'numacctsever120ppd', 'reviewstatusd', 'listd', 'fundedamount', 'acceptd', 'expd'])
# 41 set(['fundedamnt', 'lastficorangehigh', 'loanstatus', 'totalpymnt', 'issued', 'secappnumrevaccts', 'secappmthssincelastmajorderog', 'collectionrecoveryfee', 'secappcollections12mthsexmed', 'verificationstatusjoint', 'url', 'secapprevolutil', 'totalreclatefee', 'secappchargeoffwithin12mths', 'lastpymntamnt', 'lastficorangelow', 'title', 'pymntplan', 'totalrecint', 'zipcode', 'revolbaljoint', 'secappopenil6m', 'secappopenacc', 'secappficorangehigh', 'outprncp', 'totalpymntinv', 'secappficorangelow', 'recoveries', 'numacctsever120pd', 'fundedamntinv', 'verificationstatus', 'lastpymntd', 'loanamnt', 'lastcreditpulld', 'totalrecprncp', 'secappearliestcrline', 'secappmortacc', 'outprncpinv', 'policycode', 'nextpymntd', 'secappinqlast6mths'])

# %%
feature_dic={}
feature_dic['common_feature']=common_feature
feature_dic['his_unique']=his_unique
feature_dic['current_unique']=current_unique

# %%
feature_dic['current_unique']
# Out:
# {'acceptd',
#  'addrzip',
#  'creditpulld',
#  'expd',
#  'expdefaultrate',
#  'fundedamount',
#  'ilsexpd',
#  'investorcount',
#  'isincv',
#  'isincvjoint',
#  'listd',
#  'loanamount',
#  'numacctsever120ppd',
#  'reviewstatus',
#  'reviewstatusd',
#  'servicefeerate'}

# %%
feature_dic['his_unique']
# Out:
# {'collectionrecoveryfee',
#  'fundedamnt',
#  'fundedamntinv',
#  'issued',
#  'lastcreditpulld',
#  'lastficorangehigh',
#  'lastficorangelow',
#  'lastpymntamnt',
#  'lastpymntd',
#  'loanamnt',
#  'loanstatus',
#  'nextpymntd',
#  'numacctsever120pd',
#  'outprncp',
#  'outprncpinv',
#  'policycode',
#  'pymntplan',
#  'recoveries',
#  'revolbaljoint',
#  'secappchargeoffwithin12mths',
#  'secappcollections12mthsexmed',
#  'secappearliestcrline',
#  'secappficorangehigh',
#  'secappficorangelow',
#  'secappinqlast6mths',
#  'secappmortacc',
#  'secappmthssincelastmajorderog',
#  'secappnumrevaccts',
#  'secappopenacc',
#  'secappopenil6m',
#  'secapprevolutil',
#  'title',
#  'totalpymnt',
#  'totalpymntinv',
#  'totalrecint',
#  'totalreclatefee',
#  'totalrecprncp',
#  'url',
#  'verificationstatus',
#  'verificationstatusjoint',
#  'zipcode'}

# %%
feature_dic['common_feature']
# Out:
# {'accnowdelinq',
#  'accopenpast24mths',
#  'addrstate',
#  'allutil',
#  'annualinc',
#  'annualincjoint',
#  'applicationtype',
#  'avgcurbal',
#  'bcopentobuy',
#  'bcutil',
#  'chargeoffwithin12mths',
#  'collections12mthsexmed',
#  'delinq2yrs',
#  'delinqamnt',
#  'desc',
#  'dti',
#  'dtijoint',
#  'earliestcrline',
#  'emplength',
#  'emptitle',
#  'ficorangehigh',
#  'ficorangelow',
#  'grade',
#  'homeownership',
#  'id',
#  'ilutil',
#  'initialliststatus',
#  'inqfi',
#  'inqlast12m',
#  'inqlast6mths',
#  'installment',
#  'intrate',
#  'maxbalbc',
#  'memberid',
#  'mortacc',
#  'mosinoldilacct',
#  'mosinoldrevtlop',
#  'mosinrcntrevtlop',
#  'mosinrcnttl',
#  'mthssincelastdelinq',
#  'mthssincelastmajorderog',
#  'mthssincelastrecord',
#  'mthssincercntil',
#  'mthssincerecentbc',
#  'mthssincerecentbcdlq',
#  'mthssincerecentinq',
#  'mthssincerecentrevoldelinq',
#  'numactvbctl',
#  'numactvrevtl',
#  'numbcsats',
#  'numbctl',
#  'numiltl',
#  'numoprevtl',
#  'numrevaccts',
#  'numrevtlbalgt0',
#  'numsats',
#  'numtl120dpd2m',
#  'numtl30dpd',
#  'numtl90gdpd24m',
#  'numtloppast12m',
#  'openacc',
#  'openacc6m',
#  'openil12m',
#  'openil24m',
#  'openil6m',
#  'openrv12m',
#  'openrv24m',
#  'pcttlnvrdlq',
#  'percentbcgt75',
#  'pubrec',
#  'pubrecbankruptcies',
#  'purpose',
#  'revolbal',
#  'revolutil',
#  'subgrade',
#  'taxliens',
#  'term',
#  'totalacc',
#  'totalbalexmort',
#  'totalbalil',
#  'totalbclimit',
#  'totalcutl',
#  'totalilhighcreditlimit',
#  'totalrevhilim',
#  'totcollamt',
#  'totcurbal',
#  'tothicredlim'}

# %%
# add common features that have different names for current and historical data. Use the form in the historical data)

common_feature=common_feature.union({'zipcode', 
 'fundedamnt',
 'verificationstatus',
 'verificationstatusjoint',
 'loanamnt',
 'numacctsever120pd'})
len(common_feature)
# Out:
# 93

# %% [markdown]
# ### Convert column names in the data frame and save dataframe with common features and issued, loanstatus

# %%
for col in df_2014.columns.values:
    df_2014.rename(columns={str(col):str(col).replace('_','')}, inplace=True)

# %%
df_2014_1=df_2014[list(common_feature)+['issued', 'loanstatus']]

# %%
df_2014_1.shape
# Out:
# (235631, 95)

# %%
df_2014_1.to_csv('loan_2014.csv',index=False)

# %%
df=pd.read_csv('loan_2014.csv')
# Out:
# C:\Users\Weiqun\Anaconda2\lib\site-packages\IPython\core\interactiveshell.py:2723: DtypeWarning: Columns (29,55) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %% [markdown]
# ## provided data changed

# %%
df_2014_2 = pd.read_csv('LoanStats3c.csv', skiprows=1)

# %%
# previously downloaded 2014 data has 111 columns

df_2014_2.shape
# Out:
# (235631, 111)

# %% [markdown]
# ## current feature listd, acceptd

# %%
df_current.columns
# Out:
# Index([u'accNowDelinq', u'accOpenPast24Mths', u'acceptD', u'addrState',
#        u'addrZip', u'allUtil', u'annualInc', u'annualIncJoint',
#        u'applicationType', u'avgCurBal',
#        ...
#        u'totCollAmt', u'totCurBal', u'totHiCredLim', u'totalAcc',
#        u'totalBalExMort', u'totalBalIl', u'totalBcLimit', u'totalCuTl',
#        u'totalIlHighCreditLimit', u'totalRevHiLim'],
#       dtype='object', length=103)

# %%
df_current[['listD','acceptD']][:10]
# Out:
#                            listD                        acceptD
# 0  2017-06-19T14:00:00.000-07:00  2017-05-23T04:26:46.000-07:00
# 1  2017-06-19T14:00:00.000-07:00  2017-05-24T10:29:16.000-07:00
# 2  2017-06-19T14:00:00.000-07:00  2017-05-25T08:38:21.000-07:00
# 3  2017-06-19T14:00:00.000-07:00  2017-06-05T19:47:45.000-07:00
